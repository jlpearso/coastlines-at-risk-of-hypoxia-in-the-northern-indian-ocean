# %% [markdown]
# # Setup

# %%
# import packages
# %run ../global_packages.py

# get the global parameters
# %run ../global_pars.py

# import your local functions
sys.path.insert(1, '../')
from global_functions import *

# make sure the figures plot inline rather than at the end
# %matplotlib inline

# %% [markdown]
# # Paths and Parameters

# %%
figpath = '../figures/'

# %% [markdown]
# # Get Data

# %%
ds_WOD = xr.open_dataset('../data_processing/1_WOD_Coastal/wod_coastal_processed.nc')
# ds_WOD

# %% [markdown]
# # Number of Profiles per year

# %%
# # merge all data
data = np.concatenate((ds_WOD.doxy_wAS_50_200,ds_WOD.doxy_eAS_50_200,
                       ds_WOD.doxy_wBoB_50_200,ds_WOD.doxy_eBoB_50_200),0)
tdata = np.concatenate((ds_WOD.time_wAS,ds_WOD.time_eAS,
                       ds_WOD.time_wBoB,ds_WOD.time_eBoB),0)

data = xr.DataArray(data,dims = ['time'],coords =[tdata])

years = np.arange(np.min(data.time.dt.year),np.max(data.time.dt.year)+1)

no_doxy = np.full((len(years)),0)
doxy_pr_cnt = 0
for yy,year in enumerate(years):
    ind = data.time.dt.year == year
    
    tmp_data = data[ind]
    no_doxy[yy] = len(tmp_data[~np.isnan(tmp_data)])
    doxy_pr_cnt = doxy_pr_cnt + no_doxy[yy]
years.shape, no_doxy.shape,doxy_pr_cnt
# Out:
# ((63,), (63,), 3899)

# %% [markdown]
# # Domain Plot

# %%
import matplotlib.gridspec as gridspec

params = {'legend.fontsize': 6,
         'axes.labelsize': 6,
         'axes.titlesize': 8,
         'xtick.labelsize':6,
         'ytick.labelsize':6}

pylab.rcParams.update(params)
cmap = cmocean.cm.thermal_r

# limits 
cbounds = [51,104,0,30]
cmin = 20
cmax = 160
sz = 5
# clrs = ['navy','limegreen','deeppink','purple']
clrs = ['darkorange','navy','mediumorchid','darkgreen']
hyp_clr = '#FEE12B'
sla_clr = '#FEE12B'
lfz = 6
fig = plt.figure(figsize=(17.8 / 2.54,4),dpi=400)


gs0 = gridspec.GridSpec(1, 3, figure=fig)

gs00 = gs0[0].subgridspec(2, 4)

ax1 = fig.add_subplot(gs00[:-1, :])
# box = ax1.get_position()
# box.y0 = box.y0 + 0.1
# ax1.set_position(box)
ax1.set_title('ax1')

ax2 = fig.add_subplot(gs00[-1, :-2])
# box = ax2.get_position()
# box.y1 = box.y1 - 0.1
# ax2.set_position(box)
ax2.set_title('ax2')

ax3 = fig.add_subplot(gs00[-1, -2:])
# box = ax3.get_position()
# box.y1 = box.y1 - 0.1
# ax3.set_position(box)
ax3.set_title('ax3')

gs01 = gs0[1].subgridspec(2, 4)

ax4 = fig.add_subplot(gs01[:-1, :])
# box = ax4.get_position()
# box.y0 = box.y0 + 0.1
# ax4.set_position(box)
ax4.set_title('ax4')

ax5 = fig.add_subplot(gs01[-1, :-2])
# box = ax5.get_position()
# box.y1 = box.y1 - 0.1
# ax5.set_position(box)
ax5.set_title('ax5')

ax6 = fig.add_subplot(gs01[-1, -2:])
# box = ax6.get_position()
# box.y1 = box.y1 - 0.1
# ax6.set_position(box)
ax6.set_title('ax6')

ax7 = fig.add_subplot(gs0[:, 2])
box = ax7.get_position()
box.y1 = box.y1 - 0.45
ax7.set_position(box)
ax7.set_title('ax7')
# Out:
# Text(0.5, 1.0, 'ax7')

# %%
import matplotlib.gridspec as gridspec

params = {'legend.fontsize': 6.5,
         'axes.labelsize': 7,
         'axes.titlesize': 8,
         'xtick.labelsize':5.5,
         'ytick.labelsize':5.5}

pylab.rcParams.update(params)
cmap = cmocean.cm.thermal_r

# limits 
cbounds = [51,104,0,30]
cmin = 20
cmax = 160
sz = 5
# clrs = ['navy','limegreen','deeppink','purple']
clrs = ['darkorange','navy','mediumorchid','darkgreen']
hyp_clr = '#FEE12B'
sla_clr = '#FEE12B'
lfz = 6
fig = plt.figure(figsize=(17.8 / 2.54,3.5),dpi=400)


gs0 = gridspec.GridSpec(1, 3, figure=fig)

gs00 = gs0[0].subgridspec(2, 4)

gs01 = gs0[1].subgridspec(2, 4)

gs0.update(top=0.925, bottom = 0.1, left = 0.065, right = 0.975)
#############################################################
#----------------- regions ---------------------#
#############################################################
ax = fig.add_subplot(gs00[:-1, :],projection= ccrs.PlateCarree())
box = ax.get_position()
box.y0 = box.y0 + 0.05
# box.x1 = box.x1 + 0.03
# box.y0 = box.y0 + 0.1
box.x0 = box.x0 - 0.032
box.x1 = box.x1 + 0.05
ax.set_position(box)

# wAS
ind = ~np.isnan(ds_WOD.doxy_wAS_50_200)
p = ax.scatter(ds_WOD.lon_wAS[ind],ds_WOD.lat_wAS[ind],s=sz,marker = '.',c=clrs[0],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())
# eAS
ind = ~np.isnan(ds_WOD.doxy_eAS_50_200)
p = ax.scatter(ds_WOD.lon_eAS[ind],ds_WOD.lat_eAS[ind],s=sz,marker = '.',c=clrs[1],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())
# wBoB
ind = ~np.isnan(ds_WOD.doxy_wBoB_50_200)
p = ax.scatter(ds_WOD.lon_wBoB[ind],ds_WOD.lat_wBoB[ind],s=sz,marker = '.',c=clrs[2],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())
# eBoB
ind = ~np.isnan(ds_WOD.doxy_eBoB_50_200)
p = ax.scatter(ds_WOD.lon_eBoB[ind],ds_WOD.lat_eBoB[ind],s=sz,marker = '.',c=clrs[3],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())
# land
g = add_land(ax, bounds = cbounds,countries = False, rivers = True, rcolor = 'cornflowerblue')
# g.xlocator = mticker.FixedLocator(np.arange(60,110,10))
g.xlabel_style = {'size': 5.5}
g.ylabel_style = {'size': 5.5}
g.xlocator = mticker.FixedLocator([54,66,78,90,102])
add_letter(ax, 'a', x = 0.01,y=0.94, fontsize = lfz, color = 'k')
# add_single_bathy_cline(ax,200,linewidth = 0.5, color = 'dimgray')

ax.set_title('Oxygen Profile Locations')

# Seas
add_text(ax, ' Bay of \nBengal', x = 0.615,y=0.3, fontsize = 6, color = 'gray', style='italic')
add_text(ax, 'Arabian\n  Sea', x = 0.16,y=0.32, fontsize = 6, color = 'gray', style='italic')

#############################################################
#----------------- Oxygen ---------------------#
#############################################################
ax = fig.add_subplot(gs01[:-1, :],projection= ccrs.PlateCarree())
box = ax.get_position()
box.y0 = box.y0 + 0.05
# box.x0 = box.x0 - 0.03
# box.y0 = box.y0 + 0.1
box.x0 = box.x0 - 0.0575
box.x1 = box.x1 + 0.03
ax.set_position(box)

# add_bathy(ax,cbounds)

# wAS
ind = ~np.isnan(ds_WOD.doxy_wAS_50_200)
doxy = ds_WOD.doxy_wAS_50_200[ind]
lon = ds_WOD.lon_wAS[ind]
lat = ds_WOD.lat_wAS[ind]

print('Length Oxygen wAS: ', len(doxy))
print('Min Time wAS: ', np.array(np.min(ds_WOD.time_wAS[ind])))
print('Max Time wAS: ', np.array(np.max(ds_WOD.time_wAS[ind])))

ind = doxy>=80
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='skyblue',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())

ind = (doxy>=61) & (doxy<80)
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='pink',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


ind = doxy<61
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='r',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())



# eAS
ind = ~np.isnan(ds_WOD.doxy_eAS_50_200)
doxy = ds_WOD.doxy_eAS_50_200[ind]
lon = ds_WOD.lon_eAS[ind]
lat = ds_WOD.lat_eAS[ind]

print('Length Oxygen eAS: ', len(doxy))
print('Min Time eAS: ', np.array(np.min(ds_WOD.time_eAS[ind])))
print('Max Time eAS: ', np.array(np.max(ds_WOD.time_eAS[ind])))

ind = doxy>=80
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='skyblue',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())

ind = (doxy>=61) & (doxy<80)
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='pink',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


ind = doxy<61
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='r',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


# wBoB
ind = ~np.isnan(ds_WOD.doxy_wBoB_50_200)
doxy = ds_WOD.doxy_wBoB_50_200[ind]
lon = ds_WOD.lon_wBoB[ind]
lat = ds_WOD.lat_wBoB[ind]

print('Length Oxygen wBoB: ', len(doxy))
print('Min Time wBoB: ', np.array(np.min(ds_WOD.time_wBoB[ind])))
print('Max Time wBoB: ', np.array(np.max(ds_WOD.time_wBoB[ind])))

ind = doxy>=80
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='skyblue',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())

ind = (doxy>=61) & (doxy<80)
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='pink',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


ind = doxy<61
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='r',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


# eBoB
ind = ~np.isnan(ds_WOD.doxy_eBoB_50_200)
doxy = ds_WOD.doxy_eBoB_50_200[ind]
lon = ds_WOD.lon_eBoB[ind]
lat = ds_WOD.lat_eBoB[ind]

print('Length Oxygen eBoB: ', len(doxy))
print('Min Time eBoB: ', np.array(np.min(ds_WOD.time_eBoB[ind])))
print('Max Time eBoB: ', np.array(np.max(ds_WOD.time_eBoB[ind])))

ind = doxy>=80
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='skyblue',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())

ind = (doxy>=61) & (doxy<80)
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='pink',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


ind = doxy<61
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='r',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())




# land
g = add_land(ax, bounds = cbounds,countries = True, rivers = False)
g.ylabels_left = False
# g.ylabels_right = True
g.xlocator = mticker.FixedLocator([54,66,78,90,102])
g.xlabel_style = {'size': 5.5}
g.ylabel_style = {'size': 5.5}
add_letter(ax, 'b', x = 0.007,y=0.935, fontsize = lfz, color = 'k')


ax.set_title('50-200m Oxygen Values')

# countries
clr = '#481F01'
clr = 'k'
add_text(ax, 'India', x = 0.48,y=0.68, fontsize = 5, color = clr)
add_text(ax, 'Bangladesh', x = 0.61,y=0.82, fontsize = 5, color = clr)
add_text(ax, 'Pakistan', x = 0.23,y=0.91, fontsize = 5, color = clr)
add_text(ax, 'Iran', x = 0.09,y=0.92, fontsize = 5, color = clr)
add_text(ax, 'Oman', x = 0.045,y=0.58, fontsize = 5, color = clr, rotation = 50)
add_text(ax, 'Myanmar\n (Burma)', x = 0.8,y=0.63, fontsize = 5, color = clr, rotation = 0)
add_text(ax, 'Thailand', x = 0.82,y=0.48, fontsize = 5, color = clr, rotation = 0)
add_text(ax, 'Malaysia', x = 0.85,y=0.1, fontsize = 5, color = clr, rotation = -50)
add_text(ax, 'Sumatra', x = 0.8,y=0.01, fontsize = 5, color = clr, rotation = -50)
add_text(ax, 'Sri\nLanka', x = 0.54,y=0.15, fontsize = 5, color = clr)


#############################################################
#----------------- Profiles ---------------------#
#############################################################

lw = 0.1
text_fz = 5
sq_sz = 20
lfz = 7
alpha = 0.2

cmap = plt.cm.PuOr_r
cmin = -0.15
cmax = 0.15
xlim = [-10,225]
ylim = [-250,0]

#---------------------------------------------------#
# WAS ----------------------------------------------#
#---------------------------------------------------#
ax = fig.add_subplot(gs00[-1, :-2])
box = ax.get_position()
# box.y1 = box.y1 - 0.1
box.x1 = box.x1 + 0.01
box.x0 = box.x0 + 0.01
ax.set_position(box)

seas = np.array(ds_WOD.seas_wAS)
data = np.array(ds_WOD.doxy_wAS)

#winter/spring
ind = seas == 0

doxy = data[ind]
mean_doxy = np.nanmean(doxy,0)
std_doxy = np.nanstd(doxy,0)

plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0])
plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                 color = clrs[0], alpha = alpha, lw = 0)

#summer/fall
ind = seas == 1

doxy = data[ind]
mean_doxy = np.nanmean(doxy,0)
std_doxy = np.nanstd(doxy,0)

plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0], ls = ':')
plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                 color = clrs[0], alpha = alpha, lw = 0)

ax.axvspan(-10, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
#     ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.set_ylim(ylim)
ax.set_xlim(xlim)
ax.set_title('WAS')
ax.set_ylabel('Depth (m)')

ax.set_xticks([0,hyp_thresh,140,250])
ax.set_xticklabels([0,'hyp.',140,250])
add_letter(ax, 'c', x = 0.01,y=0.935, fontsize = lfz, color = 'k')

#---------------------------------------------------#
# EAS ----------------------------------------------#
#---------------------------------------------------#
ax = fig.add_subplot(gs00[-1, -2:])
box = ax.get_position()
# box.y1 = box.y1 - 0.1
box.x0 = box.x0 + 0.015
box.x1 = box.x1 + 0.015
ax.set_position(box)

seas = np.array(ds_WOD.seas_eAS)
data = np.array(ds_WOD.doxy_eAS)

#winter/spring
ind = seas == 0

doxy = data[ind]
mean_doxy = np.nanmean(doxy,0)
std_doxy = np.nanstd(doxy,0)

plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1])
plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                 color = clrs[1], alpha = alpha, lw = 0)

#summer/fall
ind = seas == 1

doxy = data[ind]
mean_doxy = np.nanmean(doxy,0)
std_doxy = np.nanstd(doxy,0)

plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1], ls = ':')
plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                 color = clrs[1], alpha = alpha, lw = 0)

ax.axvspan(-10, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
#     ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.set_ylim(ylim)
ax.set_xlim(xlim)
ax.set_title('EAS')

ax.set_xticks([0,hyp_thresh,140,250])
ax.set_xticklabels([0,'hyp.',140,250])
ax.set_yticklabels([])
add_letter(ax, 'd', x = 0.01,y=0.94, fontsize = lfz, color = 'k')

ax.set_xlabel('Dissovled Oxygen ($\mu mol/kg$)')
ax.xaxis.set_label_coords(1.1, -0.18)

#---------------------------------------------------#
# WBoB ---------------------------------------------#
#---------------------------------------------------#
ax = fig.add_subplot(gs01[-1, :-2])
box = ax.get_position()
# box.y1 = box.y1 - 0.1
box.x0 = box.x0 - 0.015
box.x1 = box.x1 - 0.015
ax.set_position(box)

seas = np.array(ds_WOD.seas_wBoB)
data = np.array(ds_WOD.doxy_wBoB)

#winter/spring
ind = seas == 0

doxy = data[ind]
mean_doxy = np.nanmean(doxy,0)
std_doxy = np.nanstd(doxy,0)

plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2])
plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                 color = clrs[2], alpha = alpha, lw = 0)

#summer/fall
ind = seas == 1

doxy = data[ind]
mean_doxy = np.nanmean(doxy,0)
std_doxy = np.nanstd(doxy,0)

plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2], ls = ':')
plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                 color = clrs[2], alpha = alpha, lw = 0)

ax.axvspan(-10, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
#     ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.set_ylim(ylim)
ax.set_xlim(xlim)
ax.set_title('WBoB')

ax.set_xticks([0,hyp_thresh,140,250])
ax.set_xticklabels([0,'hyp.',140,250])
ax.set_yticklabels([])
add_letter(ax, 'e', x = 0.01,y=0.935, fontsize = lfz, color = 'k')

#---------------------------------------------------#
# EBoB ---------------------------------------------#
#---------------------------------------------------#
ax = fig.add_subplot(gs01[-1, -2:])
box = ax.get_position()
# box.y1 = box.y1 - 0.1
box.x0 = box.x0 - 0.01
box.x1 = box.x1 - 0.01
ax.set_position(box)

seas = np.array(ds_WOD.seas_eBoB)
data = np.array(ds_WOD.doxy_eBoB)

#winter/spring
ind = seas == 0

doxy = data[ind]
mean_doxy = np.nanmean(doxy,0)
std_doxy = np.nanstd(doxy,0)

plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[3])
plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                 color = clrs[3], alpha = alpha, lw = 0)

#summer/fall
ind = seas == 1

doxy = data[ind]
mean_doxy = np.nanmean(doxy,0)
std_doxy = np.nanstd(doxy,0)

plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[3], ls = ':')
plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                 color = clrs[3], alpha = alpha, lw = 0)

ax.axvspan(-10, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
#     ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.set_ylim(ylim)
ax.set_xlim(xlim)
ax.set_title('EBoB')

ax.set_xticks([0,hyp_thresh,140,250])
ax.set_xticklabels([0,'hyp.',140,250])
ax.set_yticklabels([])
add_letter(ax, 'f', x = 0.01,y=0.94, fontsize = lfz, color = 'k')

ax.plot(np.nan,np.nan,color = 'k',ls = ':',label = 'Summer/Fall')

ax.plot(np.nan,np.nan,color = 'k',label = 'Winter/Spring')

plt.legend(fontsize = 5)

#############################################################
#----------------- Obs over time ---------------------#
#############################################################
ax = fig.add_subplot(gs0[:, 2])
box = ax.get_position()
box.y1 = box.y1 - 0.45
ax.set_position(box)
# lnclrs = ['indigo','k','limegreen']
lnclrs = ['k','y','darkgray']
ax.plot(years,no_doxy, color = lnclrs[0], linewidth = 1)
ax.fill_between(x = np.array(years),y1 = no_doxy, color = lnclrs[0], alpha=0.75)
ax.axvline(x=1993,color = lnclrs[1], linewidth = 1)
plt.fill_betweenx(y = np.arange(0,3100), x1 = 1993, x2 = 2020,
                  color = lnclrs[1],alpha=0.25)
ax.axvline(x=1997,color = lnclrs[2], linewidth = 1)
plt.fill_betweenx(y = np.arange(0,3100), x1 = 1997, x2 = 2020,
                  color = lnclrs[2],alpha=0.25)
ax.set_xlim([1948,2020])
ax.set_ylim([0,400])
add_letter(ax, 'g', x = 0.01,y=0.94, fontsize = lfz, color = 'k')

add_text(ax, 'Oxygen', x = 0.02,y=0.68, fontsize = lfz, color = lnclrs[0], weight = 'bold')
add_text(ax, 'SLA', x = 0.47,y=0.93, fontsize = lfz, color = lnclrs[1], weight = 'bold')
add_text(ax, 'CHL', x = 0.47,y=0.84, fontsize = lfz, color = lnclrs[2], weight = 'bold')

ax.set_title('No. of Observations/Year')


####### Legend ##############################################

# ax.plot(np.nan,np.nan,color = 'k',ls = ':',label = 'Summer/Fall')

# ax.plot(np.nan,np.nan,color = 'k',label = 'Winter/Spring')


ax.scatter(np.nan,np.nan,s=sz,marker = '.',c='r',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Hypoxic ($<61 \ \mu mol/kg$)')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c='pink',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Vulnerable ($61-80 \ \mu mol/kg$)')


ax.scatter(np.nan,np.nan,s=sz,marker = '.',c='skyblue',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = '$>80 \  \mu mol/kg$')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c=clrs[0],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Western Arabian Sea (WAS)')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c=clrs[1],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Eastern Arabian Sea (EAS)')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c=clrs[2],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Western Bay of Bengal (WBoB)')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c=clrs[3],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Eastern Bay of Bengal (EBoB)')



l = ax.legend(loc='lower center', bbox_to_anchor=(.5, 1.3),
              markerscale = 6,ncol = 1, columnspacing = 1.5,
              facecolor = 'w',framealpha=1,handletextpad=1, 
              labelspacing = 0.75,handlelength=1.25);

# l = ax.legend(loc='lower center', bbox_to_anchor=(.5, 1.28),
#               markerscale = 6,ncol = 1, columnspacing = 1.5,
#               facecolor = 'w',framealpha=1,handletextpad=1, 
#               labelspacing = 0.75,handlelength=1.25);

# gs.update(top=0.95)

plt.savefig(figpath + 'Fig_1_domain_and_profiles.pdf', format='pdf', dpi = 400)
# Out:
# Length Oxygen wAS:  629
# Min Time wAS:  1960-11-04T00:00:00.000000000
# Max Time wAS:  2013-07-05T00:00:00.000000000
# Length Oxygen eAS:  1906
# Min Time eAS:  1958-11-27T00:00:00.000000000
# Max Time eAS:  2020-05-24T00:00:00.000000000
# Length Oxygen wBoB:  291
# Min Time wBoB:  1961-01-30T00:00:00.000000000
# Max Time wBoB:  2018-07-24T00:00:00.000000000
# Length Oxygen eBoB:  1073
# Min Time eBoB:  1959-09-29T00:00:00.000000000
# Max Time eBoB:  2018-07-10T00:00:00.000000000
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:248: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:259: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:297: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:308: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:349: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:360: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:398: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:409: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)

# %%
import matplotlib.gridspec as gridspec

params = {'legend.fontsize': 5.25,
         'axes.labelsize': 6,
         'axes.titlesize': 8,
         'xtick.labelsize':5.5,
         'ytick.labelsize':5.5}

pylab.rcParams.update(params)
cmap = cmocean.cm.thermal_r

# limits 
cbounds = [51,104,0,30]
cmin = 20
cmax = 160
sz = 5
# clrs = ['navy','limegreen','deeppink','purple']
clrs = ['darkorange','navy','mediumorchid','darkgreen']
hyp_clr = '#FEE12B'
sla_clr = '#FEE12B'
lfz = 6
fig = plt.figure(figsize=(17.8 / 2.54,3.5),dpi=400)


gs0 = gridspec.GridSpec(1, 3, figure=fig)

gs00 = gs0[0].subgridspec(2, 4)

gs01 = gs0[1].subgridspec(2, 4)

gs0.update(top=0.925, bottom = 0.1, left = 0.065, right = 0.975)
#############################################################
#----------------- regions ---------------------#
#############################################################
ax = fig.add_subplot(gs00[:-1, :],projection= ccrs.PlateCarree())
box = ax.get_position()
# box.y0 = box.y0 + 0.1
# box.x1 = box.x1 + 0.03
box.y0 = box.y0 + 0.1
box.x0 = box.x0 - 0.025
box.x1 = box.x1 + 0.04
ax.set_position(box)

# wAS
ind = ~np.isnan(ds_WOD.doxy_wAS_50_200)
p = ax.scatter(ds_WOD.lon_wAS[ind],ds_WOD.lat_wAS[ind],s=sz,marker = '.',c=clrs[0],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())
# eAS
ind = ~np.isnan(ds_WOD.doxy_eAS_50_200)
p = ax.scatter(ds_WOD.lon_eAS[ind],ds_WOD.lat_eAS[ind],s=sz,marker = '.',c=clrs[1],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())
# wBoB
ind = ~np.isnan(ds_WOD.doxy_wBoB_50_200)
p = ax.scatter(ds_WOD.lon_wBoB[ind],ds_WOD.lat_wBoB[ind],s=sz,marker = '.',c=clrs[2],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())
# eBoB
ind = ~np.isnan(ds_WOD.doxy_eBoB_50_200)
p = ax.scatter(ds_WOD.lon_eBoB[ind],ds_WOD.lat_eBoB[ind],s=sz,marker = '.',c=clrs[3],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())
# land
g = add_land(ax, bounds = cbounds,countries = False, rivers = True, rcolor = 'cornflowerblue')
# g.xlocator = mticker.FixedLocator(np.arange(60,110,10))
g.xlabel_style = {'size': 5.5}
g.ylabel_style = {'size': 5.5}
g.xlocator = mticker.FixedLocator([54,66,78,90,102])
add_letter(ax, 'a', x = 0.01,y=0.92, fontsize = lfz, color = 'k')
# add_single_bathy_cline(ax,200,linewidth = 0.5, color = 'dimgray')

ax.set_title('Oxygen Profile Locations')

# Seas
add_text(ax, ' Bay of \nBengal', x = 0.615,y=0.3, fontsize = 6, color = 'gray', style='italic')
add_text(ax, 'Arabian\n  Sea', x = 0.16,y=0.32, fontsize = 6, color = 'gray', style='italic')

#############################################################
#----------------- Oxygen ---------------------#
#############################################################
ax = fig.add_subplot(gs01[:-1, :],projection= ccrs.PlateCarree())
box = ax.get_position()
# box.y0 = box.y0 + 0.1
# box.x0 = box.x0 - 0.03
box.y0 = box.y0 + 0.1
box.x0 = box.x0 - 0.05
box.x1 = box.x1 + 0.015
ax.set_position(box)

# add_bathy(ax,cbounds)

# wAS
ind = ~np.isnan(ds_WOD.doxy_wAS_50_200)
doxy = ds_WOD.doxy_wAS_50_200[ind]
lon = ds_WOD.lon_wAS[ind]
lat = ds_WOD.lat_wAS[ind]

print('Length Oxygen wAS: ', len(doxy))
print('Min Time wAS: ', np.array(np.min(ds_WOD.time_wAS[ind])))
print('Max Time wAS: ', np.array(np.max(ds_WOD.time_wAS[ind])))

ind = doxy>=80
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='skyblue',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())

ind = (doxy>=61) & (doxy<80)
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='pink',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


ind = doxy<61
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='r',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())



# eAS
ind = ~np.isnan(ds_WOD.doxy_eAS_50_200)
doxy = ds_WOD.doxy_eAS_50_200[ind]
lon = ds_WOD.lon_eAS[ind]
lat = ds_WOD.lat_eAS[ind]

print('Length Oxygen eAS: ', len(doxy))
print('Min Time eAS: ', np.array(np.min(ds_WOD.time_eAS[ind])))
print('Max Time eAS: ', np.array(np.max(ds_WOD.time_eAS[ind])))

ind = doxy>=80
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='skyblue',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())

ind = (doxy>=61) & (doxy<80)
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='pink',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


ind = doxy<61
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='r',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


# wBoB
ind = ~np.isnan(ds_WOD.doxy_wBoB_50_200)
doxy = ds_WOD.doxy_wBoB_50_200[ind]
lon = ds_WOD.lon_wBoB[ind]
lat = ds_WOD.lat_wBoB[ind]

print('Length Oxygen wBoB: ', len(doxy))
print('Min Time wBoB: ', np.array(np.min(ds_WOD.time_wBoB[ind])))
print('Max Time wBoB: ', np.array(np.max(ds_WOD.time_wBoB[ind])))

ind = doxy>=80
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='skyblue',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())

ind = (doxy>=61) & (doxy<80)
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='pink',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


ind = doxy<61
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='r',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


# eBoB
ind = ~np.isnan(ds_WOD.doxy_eBoB_50_200)
doxy = ds_WOD.doxy_eBoB_50_200[ind]
lon = ds_WOD.lon_eBoB[ind]
lat = ds_WOD.lat_eBoB[ind]

print('Length Oxygen eBoB: ', len(doxy))
print('Min Time eBoB: ', np.array(np.min(ds_WOD.time_eBoB[ind])))
print('Max Time eBoB: ', np.array(np.max(ds_WOD.time_eBoB[ind])))

ind = doxy>=80
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='skyblue',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())

ind = (doxy>=61) & (doxy<80)
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='pink',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


ind = doxy<61
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='r',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())




# land
g = add_land(ax, bounds = cbounds,countries = True, rivers = False)
g.ylabels_left = False
# g.ylabels_right = True
g.xlocator = mticker.FixedLocator([54,66,78,90,102])
g.xlabel_style = {'size': 5.5}
g.ylabel_style = {'size': 5.5}
add_letter(ax, 'b', x = 0.007,y=0.92, fontsize = lfz, color = 'k')


ax.set_title('50-200m Oxygen Values')

# countries
clr = '#481F01'
clr = 'k'
add_text(ax, 'India', x = 0.48,y=0.68, fontsize = 5, color = clr)
add_text(ax, 'Bangladesh', x = 0.61,y=0.82, fontsize = 5, color = clr)
add_text(ax, 'Pakistan', x = 0.23,y=0.91, fontsize = 5, color = clr)
add_text(ax, 'Iran', x = 0.09,y=0.92, fontsize = 5, color = clr)
add_text(ax, 'Oman', x = 0.045,y=0.58, fontsize = 5, color = clr, rotation = 50)
add_text(ax, 'Myanmar\n (Burma)', x = 0.8,y=0.63, fontsize = 5, color = clr, rotation = 0)
add_text(ax, 'Thailand', x = 0.82,y=0.48, fontsize = 5, color = clr, rotation = 0)
add_text(ax, 'Malaysia', x = 0.85,y=0.1, fontsize = 5, color = clr, rotation = -50)
add_text(ax, 'Sumatra', x = 0.8,y=0.01, fontsize = 5, color = clr, rotation = -50)
add_text(ax, 'Sri\nLanka', x = 0.54,y=0.15, fontsize = 5, color = clr)


#############################################################
#----------------- Profiles ---------------------#
#############################################################

lw = 0.1
text_fz = 5
sq_sz = 20
lfz = 7
alpha = 0.2

cmap = plt.cm.PuOr_r
cmin = -0.15
cmax = 0.15
xlim = [-10,225]
ylim = [-250,0]

#---------------------------------------------------#
# WAS ----------------------------------------------#
#---------------------------------------------------#
ax = fig.add_subplot(gs00[-1, :-2])
box = ax.get_position()
box.y1 = box.y1 - 0.1
box.x1 = box.x1 + 0.01
box.x0 = box.x0 + 0.01
ax.set_position(box)

seas = np.array(ds_WOD.seas_wAS)
data = np.array(ds_WOD.doxy_wAS)

#winter/spring
ind = seas == 0

doxy = data[ind]
mean_doxy = np.nanmean(doxy,0)
std_doxy = np.nanstd(doxy,0)

plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0])
plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                 color = clrs[0], alpha = alpha, lw = 0)

#summer/fall
ind = seas == 1

doxy = data[ind]
mean_doxy = np.nanmean(doxy,0)
std_doxy = np.nanstd(doxy,0)

plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0], ls = ':')
plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                 color = clrs[0], alpha = alpha, lw = 0)

ax.axvspan(-10, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
#     ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.set_ylim(ylim)
ax.set_xlim(xlim)
ax.set_title('WAS')
ax.set_ylabel('Depth (m)')

ax.set_xticks([0,hyp_thresh,140,250])
ax.set_xticklabels([0,'hyp.',140,250])
add_letter(ax, 'd', x = 0.01,y=0.9, fontsize = lfz, color = 'k')

#---------------------------------------------------#
# EAS ----------------------------------------------#
#---------------------------------------------------#
ax = fig.add_subplot(gs00[-1, -2:])
box = ax.get_position()
box.y1 = box.y1 - 0.1
box.x0 = box.x0 + 0.015
box.x1 = box.x1 + 0.015
ax.set_position(box)

seas = np.array(ds_WOD.seas_eAS)
data = np.array(ds_WOD.doxy_eAS)

#winter/spring
ind = seas == 0

doxy = data[ind]
mean_doxy = np.nanmean(doxy,0)
std_doxy = np.nanstd(doxy,0)

plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1])
plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                 color = clrs[1], alpha = alpha, lw = 0)

#summer/fall
ind = seas == 1

doxy = data[ind]
mean_doxy = np.nanmean(doxy,0)
std_doxy = np.nanstd(doxy,0)

plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1], ls = ':')
plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                 color = clrs[1], alpha = alpha, lw = 0)

ax.axvspan(-10, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
#     ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.set_ylim(ylim)
ax.set_xlim(xlim)
ax.set_title('EAS')

ax.set_xticks([0,hyp_thresh,140,250])
ax.set_xticklabels([0,'hyp.',140,250])
ax.set_yticklabels([])
add_letter(ax, 'e', x = 0.01,y=0.905, fontsize = lfz, color = 'k')

ax.set_xlabel('Dissovled Oxygen ($\mu mol/kg$)')
ax.xaxis.set_label_coords(1.1, -0.25)

#---------------------------------------------------#
# WBoB ---------------------------------------------#
#---------------------------------------------------#
ax = fig.add_subplot(gs01[-1, :-2])
box = ax.get_position()
box.y1 = box.y1 - 0.1
box.x0 = box.x0 - 0.015
box.x1 = box.x1 - 0.015
ax.set_position(box)

seas = np.array(ds_WOD.seas_wBoB)
data = np.array(ds_WOD.doxy_wBoB)

#winter/spring
ind = seas == 0

doxy = data[ind]
mean_doxy = np.nanmean(doxy,0)
std_doxy = np.nanstd(doxy,0)

plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2])
plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                 color = clrs[2], alpha = alpha, lw = 0)

#summer/fall
ind = seas == 1

doxy = data[ind]
mean_doxy = np.nanmean(doxy,0)
std_doxy = np.nanstd(doxy,0)

plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2], ls = ':')
plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                 color = clrs[2], alpha = alpha, lw = 0)

ax.axvspan(-10, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
#     ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.set_ylim(ylim)
ax.set_xlim(xlim)
ax.set_title('WBoB')

ax.set_xticks([0,hyp_thresh,140,250])
ax.set_xticklabels([0,'hyp.',140,250])
ax.set_yticklabels([])
add_letter(ax, 'f', x = 0.01,y=0.9, fontsize = lfz, color = 'k')

#---------------------------------------------------#
# EBoB ---------------------------------------------#
#---------------------------------------------------#
ax = fig.add_subplot(gs01[-1, -2:])
box = ax.get_position()
box.y1 = box.y1 - 0.1
box.x0 = box.x0 - 0.01
box.x1 = box.x1 - 0.01
ax.set_position(box)

seas = np.array(ds_WOD.seas_eBoB)
data = np.array(ds_WOD.doxy_eBoB)

#winter/spring
ind = seas == 0

doxy = data[ind]
mean_doxy = np.nanmean(doxy,0)
std_doxy = np.nanstd(doxy,0)

plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[3])
plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                 color = clrs[3], alpha = alpha, lw = 0)

#summer/fall
ind = seas == 1

doxy = data[ind]
mean_doxy = np.nanmean(doxy,0)
std_doxy = np.nanstd(doxy,0)

plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[3], ls = ':')
plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                 color = clrs[3], alpha = alpha, lw = 0)

ax.axvspan(-10, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
#     ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.set_ylim(ylim)
ax.set_xlim(xlim)
ax.set_title('EBoB')

ax.set_xticks([0,hyp_thresh,140,250])
ax.set_xticklabels([0,'hyp.',140,250])
ax.set_yticklabels([])
add_letter(ax, 'g', x = 0.01,y=0.905, fontsize = lfz, color = 'k')

#############################################################
#----------------- Obs over time ---------------------#
#############################################################
ax = fig.add_subplot(gs0[:, 2])
lnclrs = ['indigo','k','limegreen']
ax.plot(years,no_doxy, color = lnclrs[0], linewidth = 1)
ax.fill_between(x = np.array(years),y1 = no_doxy, color = lnclrs[0], alpha=0.75)
ax.axvline(x=1993,color = lnclrs[1], linewidth = 1)
plt.fill_betweenx(y = np.arange(0,3100), x1 = 1993, x2 = 2020,
                  color = lnclrs[1],alpha=0.25)
ax.axvline(x=1997,color = lnclrs[2], linewidth = 1)
plt.fill_betweenx(y = np.arange(0,3100), x1 = 1997, x2 = 2020,
                  color = lnclrs[2],alpha=0.25)
ax.set_xlim([1948,2020])
ax.set_ylim([0,400])
add_letter(ax, 'c', x = 0.01,y=0.97, fontsize = lfz, color = 'k')

add_text(ax, 'Oxygen', x = 0.02,y=0.68, fontsize = lfz, color = lnclrs[0], weight = 'bold')
add_text(ax, 'SLA', x = 0.47,y=0.93, fontsize = lfz, color = lnclrs[1], weight = 'bold')
add_text(ax, 'CHL', x = 0.47,y=0.875, fontsize = lfz, color = lnclrs[2], weight = 'bold')

ax.set_title('No. of Observations/Year')


####### Legend ##############################################

ax.plot(np.nan,np.nan,color = 'k',ls = ':',label = 'Summer/Fall')

ax.plot(np.nan,np.nan,color = 'k',label = 'Winter/Spring')


ax.scatter(np.nan,np.nan,s=sz,marker = '.',c='r',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Hypoxic ($<61 \mu mol/kg$)')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c=clrs[0],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Western Arabian Sea')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c=clrs[2],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Western Bay of Bengal')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c='pink',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Vulnerable ($61-80 \mu mol/kg$)')

# ax.scatter(np.nan,np.nan,s=sz,marker = '.',c='none',cmap=cmap,vmin=cmin,vmax=cmax,
#                        edgecolor = 'none', label = ' ')

# ax.scatter(np.nan,np.nan,s=1.75,marker = '*',c='k',
#                        edgecolor = 'k', label = 'Reported Cases of Hypoxia',linewidth=0.5)

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c=clrs[1],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Eastern Arabian Sea')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c=clrs[3],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Eastern Bay of Bengal')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c='skyblue',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = '$>80 \mu mol/kg$')




l = ax.legend(loc='lower center', bbox_to_anchor=(-1.32, .415),
              markerscale = 5,ncol = 3, columnspacing = 1.25,
              facecolor = 'w',framealpha=1,handletextpad=1, 
              labelspacing = 0.75,handlelength=1);

# fig.set_tight_layout(True)

# gs.update(top=0.95)

# plt.savefig(figpath + 'Fig_1_domain_and_profiles.pdf', format='pdf', dpi = 400)
# Out:
# Length Oxygen wAS:  629
# Min Time wAS:  1960-11-04T00:00:00.000000000
# Max Time wAS:  2013-07-05T00:00:00.000000000
# Length Oxygen eAS:  1906
# Min Time eAS:  1958-11-27T00:00:00.000000000
# Max Time eAS:  2020-05-24T00:00:00.000000000
# Length Oxygen wBoB:  291
# Min Time wBoB:  1961-01-30T00:00:00.000000000
# Max Time wBoB:  2018-07-24T00:00:00.000000000
# Length Oxygen eBoB:  1073
# Min Time eBoB:  1959-09-29T00:00:00.000000000
# Max Time eBoB:  2018-07-10T00:00:00.000000000
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:248: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:259: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:297: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:308: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:349: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:360: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:398: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:409: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)

# %%
import matplotlib.gridspec as gridspec

params = {'legend.fontsize': 6,
         'axes.labelsize': 6,
         'axes.titlesize': 8,
         'xtick.labelsize':6,
         'ytick.labelsize':6}

pylab.rcParams.update(params)
cmap = cmocean.cm.thermal_r

# limits 
cbounds = [51,104,0,30]
cmin = 20
cmax = 160
sz = 5
# clrs = ['navy','limegreen','deeppink','purple']
clrs = ['darkorange','navy','mediumorchid','darkgreen']
hyp_clr = '#FEE12B'
sla_clr = '#FEE12B'
lfz = 6
fig = plt.figure(figsize=(17.8 / 2.54,4),dpi=400)


gs0 = gridspec.GridSpec(1, 3, figure=fig)

gs00 = gs0[0].subgridspec(2, 4)

ax1 = fig.add_subplot(gs00[:-1, :])
box = ax1.get_position()
box.y0 = box.y0 + 0.1
ax1.set_position(box)

ax2 = fig.add_subplot(gs00[-1, :-2])
box = ax2.get_position()
box.y1 = box.y1 - 0.1
ax2.set_position(box)


ax3 = fig.add_subplot(gs00[-1, -2:])
box = ax3.get_position()
box.y1 = box.y1 - 0.1
ax3.set_position(box)

gs01 = gs0[1].subgridspec(2, 4)

ax4 = fig.add_subplot(gs01[:-1, :])
box = ax4.get_position()
box.y0 = box.y0 + 0.1
ax4.set_position(box)

ax5 = fig.add_subplot(gs01[-1, :-2])
box = ax5.get_position()
box.y1 = box.y1 - 0.1
ax5.set_position(box)

ax6 = fig.add_subplot(gs01[-1, -2:])
box = ax6.get_position()
box.y1 = box.y1 - 0.1
ax6.set_position(box)

ax7 = fig.add_subplot(gs0[:, 2])

# %%
# # Plotting Full Indian Ocean

params = {'legend.fontsize': 6,
         'axes.labelsize': 6,
         'axes.titlesize': 8,
         'xtick.labelsize':6,
         'ytick.labelsize':6}

pylab.rcParams.update(params)
cmap = cmocean.cm.thermal_r

# limits 
cbounds = [51,104,0,30]
cmin = 20
cmax = 160
sz = 5
# clrs = ['navy','limegreen','deeppink','purple']
clrs = ['darkorange','navy','mediumorchid','darkgreen']
hyp_clr = '#FEE12B'
sla_clr = '#FEE12B'
lfz = 6
fig = plt.figure(figsize=(17.8 / 2.54,2.35),dpi=400)

#############################################################
#----------------- regions ---------------------#
#############################################################
ax = fig.add_subplot(131,projection= ccrs.PlateCarree())
plt.subplots_adjust(wspace = 0.15, bottom = 0.4, left = 0.05, right = 0.95)
# add_bathy(ax,cbounds)

# wAS
ind = ~np.isnan(ds_WOD.doxy_wAS_50_200)
p = ax.scatter(ds_WOD.lon_wAS[ind],ds_WOD.lat_wAS[ind],s=sz,marker = '.',c=clrs[0],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())
# eAS
ind = ~np.isnan(ds_WOD.doxy_eAS_50_200)
p = ax.scatter(ds_WOD.lon_eAS[ind],ds_WOD.lat_eAS[ind],s=sz,marker = '.',c=clrs[1],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())
# wBoB
ind = ~np.isnan(ds_WOD.doxy_wBoB_50_200)
p = ax.scatter(ds_WOD.lon_wBoB[ind],ds_WOD.lat_wBoB[ind],s=sz,marker = '.',c=clrs[2],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())
# eBoB
ind = ~np.isnan(ds_WOD.doxy_eBoB_50_200)
p = ax.scatter(ds_WOD.lon_eBoB[ind],ds_WOD.lat_eBoB[ind],s=sz,marker = '.',c=clrs[3],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())
# land
g = add_land(ax, bounds = cbounds,countries = False, rivers = True, rcolor = 'cornflowerblue')
# g.xlocator = mticker.FixedLocator(np.arange(60,110,10))
g.xlabel_style = {'size': 5.5}
g.ylabel_style = {'size': 5.5}
g.xlocator = mticker.FixedLocator([54,66,78,90,102])
add_letter(ax, 'a', x = 0.01,y=0.94, fontsize = lfz, color = 'k')
# add_single_bathy_cline(ax,200,linewidth = 0.5, color = 'dimgray')

ax.set_title('Oxygen Profile Locations')

# Seas
add_text(ax, ' Bay of \nBengal', x = 0.615,y=0.3, fontsize = 6, color = 'gray', style='italic')
add_text(ax, 'Arabian\n  Sea', x = 0.16,y=0.32, fontsize = 6, color = 'gray', style='italic')

# ####### Hypoxia ##############################################

# hsz = 30
# halpha = 1

# ind = ds_HE.etype == 1
# ax.scatter(ds_HE.lon[ind],ds_HE.lat[ind],s=hsz,marker = '*',c=hyp_clr,alpha = halpha,
#                        edgecolor = 'k',transform=ccrs.PlateCarree(), zorder = 4,linewidth=0.5)

# newlat = [25.6,17.69,17.69,13,10,18.9,17,15.6,14.1,13,11.5,10,8,11,12,13]
# newlon = [52.4,57.08,57.08,74.5,76,72.6,73,73.4,74,74.5,75.2,76,77,79.5,79.8,80]

# ax.scatter(newlon,newlat,s=hsz,marker = '*',c='w',alpha = halpha,
#                        edgecolor = 'k',transform=ccrs.PlateCarree(), zorder = 4,linewidth=0.5)

#############################################################
#----------------- Oxygen ---------------------#
#############################################################
ax = fig.add_subplot(132,projection= ccrs.PlateCarree())
box = ax.get_position()
box.x0 = box.x0 - 0.08
box.x1 = box.x1 + 0.04
ax.set_position(box)

# add_bathy(ax,cbounds)

# wAS
ind = ~np.isnan(ds_WOD.doxy_wAS_50_200)
doxy = ds_WOD.doxy_wAS_50_200[ind]
lon = ds_WOD.lon_wAS[ind]
lat = ds_WOD.lat_wAS[ind]

print('Length Oxygen wAS: ', len(doxy))
print('Min Time wAS: ', np.array(np.min(ds_WOD.time_wAS[ind])))
print('Max Time wAS: ', np.array(np.max(ds_WOD.time_wAS[ind])))

ind = doxy>=80
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='skyblue',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())

ind = (doxy>=61) & (doxy<80)
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='pink',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


ind = doxy<61
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='r',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())



# eAS
ind = ~np.isnan(ds_WOD.doxy_eAS_50_200)
doxy = ds_WOD.doxy_eAS_50_200[ind]
lon = ds_WOD.lon_eAS[ind]
lat = ds_WOD.lat_eAS[ind]

print('Length Oxygen eAS: ', len(doxy))
print('Min Time eAS: ', np.array(np.min(ds_WOD.time_eAS[ind])))
print('Max Time eAS: ', np.array(np.max(ds_WOD.time_eAS[ind])))

ind = doxy>=80
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='skyblue',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())

ind = (doxy>=61) & (doxy<80)
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='pink',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


ind = doxy<61
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='r',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


# wBoB
ind = ~np.isnan(ds_WOD.doxy_wBoB_50_200)
doxy = ds_WOD.doxy_wBoB_50_200[ind]
lon = ds_WOD.lon_wBoB[ind]
lat = ds_WOD.lat_wBoB[ind]

print('Length Oxygen wBoB: ', len(doxy))
print('Min Time wBoB: ', np.array(np.min(ds_WOD.time_wBoB[ind])))
print('Max Time wBoB: ', np.array(np.max(ds_WOD.time_wBoB[ind])))

ind = doxy>=80
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='skyblue',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())

ind = (doxy>=61) & (doxy<80)
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='pink',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


ind = doxy<61
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='r',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


# eBoB
ind = ~np.isnan(ds_WOD.doxy_eBoB_50_200)
doxy = ds_WOD.doxy_eBoB_50_200[ind]
lon = ds_WOD.lon_eBoB[ind]
lat = ds_WOD.lat_eBoB[ind]

print('Length Oxygen eBoB: ', len(doxy))
print('Min Time eBoB: ', np.array(np.min(ds_WOD.time_eBoB[ind])))
print('Max Time eBoB: ', np.array(np.max(ds_WOD.time_eBoB[ind])))

ind = doxy>=80
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='skyblue',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())

ind = (doxy>=61) & (doxy<80)
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='pink',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())


ind = doxy<61
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',c='r',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())




# land
g = add_land(ax, bounds = cbounds,countries = True, rivers = False)
g.ylabels_left = False
# g.ylabels_right = True
g.xlocator = mticker.FixedLocator([54,66,78,90,102])
g.xlabel_style = {'size': 5.5}
g.ylabel_style = {'size': 5.5}
add_letter(ax, 'b', x = 0.007,y=0.93, fontsize = lfz, color = 'k')


ax.set_title('50-200m Oxygen Values')

# countries
clr = '#481F01'
clr = 'k'
add_text(ax, 'India', x = 0.48,y=0.68, fontsize = 6, color = clr)
add_text(ax, 'Bangladesh', x = 0.61,y=0.82, fontsize = 6, color = clr)
add_text(ax, 'Pakistan', x = 0.23,y=0.91, fontsize = 6, color = clr)
add_text(ax, 'Iran', x = 0.09,y=0.92, fontsize = 6, color = clr)
add_text(ax, 'Oman', x = 0.045,y=0.58, fontsize = 6, color = clr, rotation = 50)
add_text(ax, 'Myanmar\n (Burma)', x = 0.8,y=0.63, fontsize = 6, color = clr, rotation = 0)
add_text(ax, 'Thailand', x = 0.82,y=0.48, fontsize = 6, color = clr, rotation = 0)
add_text(ax, 'Malaysia', x = 0.85,y=0.1, fontsize = 6, color = clr, rotation = -50)
add_text(ax, 'Sumatra', x = 0.8,y=0.01, fontsize = 6, color = clr, rotation = -50)
add_text(ax, 'Sri\nLanka', x = 0.54,y=0.15, fontsize = 6, color = clr)


#############################################################
#----------------- Obs over time ---------------------#
#############################################################
lnclrs = ['indigo','k','limegreen']
ax = fig.add_subplot(133)
box = ax.get_position()
box.y0 = box.y0 - 0.25
ax.set_position(box)

ax.plot(years,no_doxy, color = lnclrs[0], linewidth = 1)
ax.fill_between(x = np.array(years),y1 = no_doxy, color = lnclrs[0], alpha=0.75)
ax.axvline(x=1993,color = lnclrs[1], linewidth = 1)
plt.fill_betweenx(y = np.arange(0,3100), x1 = 1993, x2 = 2020,
                  color = lnclrs[1],alpha=0.25)
ax.axvline(x=1997,color = lnclrs[2], linewidth = 1)
plt.fill_betweenx(y = np.arange(0,3100), x1 = 1997, x2 = 2020,
                  color = lnclrs[2],alpha=0.25)
ax.set_xlim([1948,2020])
ax.set_ylim([0,350])
add_letter(ax, 'c', x = 0.01,y=0.96, fontsize = lfz, color = 'k')

ax.set_title('No. of Observations/Year')

####### Legend ##############################################
add_text(ax, 'Oxygen', x = 0.04,y=0.62, fontsize = lfz, color = lnclrs[0], weight = 'bold')
add_text(ax, 'SLA', x = 0.47,y=0.93, fontsize = lfz, color = lnclrs[1], weight = 'bold')
add_text(ax, 'CHL', x = 0.47,y=0.875, fontsize = lfz, color = lnclrs[2], weight = 'bold')


####### Legend ##############################################
ax.scatter(np.nan,np.nan,s=sz,marker = '.',c=clrs[0],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Western Arabian Sea')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c=clrs[2],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Western Bay of Bengal')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c='none',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = ' ')

# ax.scatter(np.nan,np.nan,s=1.75,marker = '*',c='k',
#                        edgecolor = 'k', label = 'Reported Cases of Hypoxia',linewidth=0.5)

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c=clrs[1],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Eastern Arabian Sea')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c=clrs[3],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Eastern Bay of Bengal')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c='none',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = ' ')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c='none',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = ' ')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c='none',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = ' ')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c='none',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = ' ')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c='r',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Hypoxic ($<61 \mu mol/kg$)')


ax.scatter(np.nan,np.nan,s=sz,marker = '.',c='pink',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = 'Vulnerable ($61-80 \mu mol/kg$)')

ax.scatter(np.nan,np.nan,s=sz,marker = '.',c='skyblue',cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none', label = '$>80 \mu mol/kg$')




l = ax.legend(loc='lower center', bbox_to_anchor=(-1.256, -.12),
              markerscale = 5,ncol = 4, columnspacing = 0.5,
              facecolor = 'w',framealpha=1,handletextpad=0.05, 
              labelspacing = 0.75);

# plt.savefig(figpath + 'Fig_1_domain.pdf', format='pdf', dpi = 400)
# Out:
# Length Oxygen wAS:  629
# Min Time wAS:  1960-11-04T00:00:00.000000000
# Max Time wAS:  2013-07-05T00:00:00.000000000
# Length Oxygen eAS:  1906
# Min Time eAS:  1958-11-27T00:00:00.000000000
# Max Time eAS:  2020-05-24T00:00:00.000000000
# Length Oxygen wBoB:  291
# Min Time wBoB:  1961-01-30T00:00:00.000000000
# Max Time wBoB:  2018-07-24T00:00:00.000000000
# Length Oxygen eBoB:  1073
# Min Time eBoB:  1959-09-29T00:00:00.000000000
# Max Time eBoB:  2018-07-10T00:00:00.000000000

# %%
# # Plotting Full Indian Ocean

params = {'legend.fontsize': 6,
         'axes.labelsize': 6,
         'axes.titlesize': 8,
         'xtick.labelsize':6,
         'ytick.labelsize':6}

pylab.rcParams.update(params)
cmap = cmocean.cm.thermal_r

# limits 
cbounds = [51,104,0,30]
cmin = 20
cmax = 160
sz = 5
# clrs = ['navy','limegreen','deeppink','purple']
clrs = ['darkorange','navy','mediumorchid','darkgreen']
hyp_clr = '#FEE12B'
sla_clr = '#FEE12B'
lfz = 6
fig = plt.figure(figsize=(4,3.5),dpi=400)


#############################################################
#----------------- regions ---------------------#
#############################################################
ax = fig.add_subplot(111,projection= ccrs.PlateCarree())
plt.subplots_adjust(wspace = 0.15, bottom = 0.4, left = 0.05, right = 0.95)
# add_bathy(ax,cbounds)

data = np.concatenate((ds_WOD.nitrate_wAS_50_200,ds_WOD.nitrate_eAS_50_200,
                       ds_WOD.nitrate_wBoB_50_200,ds_WOD.nitrate_eBoB_50_200),0)
lat = np.concatenate((ds_WOD.lat_wAS,ds_WOD.lat_eAS,
                       ds_WOD.lat_wBoB,ds_WOD.lat_eBoB),0)
lon = np.concatenate((ds_WOD.lon_wAS,ds_WOD.lon_eAS,
                       ds_WOD.lon_wBoB,ds_WOD.lon_eBoB),0)
tdata = np.concatenate((ds_WOD.time_wAS,ds_WOD.time_eAS,
                       ds_WOD.time_wBoB,ds_WOD.time_eBoB),0)
# data.time.dt.year
ind = ~np.isnan(data)
data = data[ind]
tdata = tdata[ind]
lat = lat[ind]
lon = lon[ind]

data = xr.DataArray(data,dims = ['time'],coords =[tdata])

ind = data.time.dt.year > 1995
p = ax.scatter(lon[ind],lat[ind],s=sz,marker = '.',color='r',vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())
print(lon[ind].shape)
# # wAS
# ind = (~np.isnan(ds_WOD.doxy_wAS_50_200)) & (years>1995)
# p = ax.scatter(ds_WOD.lon_wAS[ind],ds_WOD.lat_wAS[ind],s=sz,marker = '.',c=clrs[0],cmap=cmap,vmin=cmin,vmax=cmax,
#                        edgecolor = 'none',transform=ccrs.PlateCarree())
# # eAS
# ind = (~np.isnan(ds_WOD.doxy_eAS_50_200)) & (years>1995)
# p = ax.scatter(ds_WOD.lon_eAS[ind],ds_WOD.lat_eAS[ind],s=sz,marker = '.',c=clrs[1],cmap=cmap,vmin=cmin,vmax=cmax,
#                        edgecolor = 'none',transform=ccrs.PlateCarree())
# # wBoB
# ind = (~np.isnan(ds_WOD.doxy_wBoB_50_200)) & (years>1995)
# p = ax.scatter(ds_WOD.lon_wBoB[ind],ds_WOD.lat_wBoB[ind],s=sz,marker = '.',c=clrs[2],cmap=cmap,vmin=cmin,vmax=cmax,
#                        edgecolor = 'none',transform=ccrs.PlateCarree())
# # eBoB
# ind = (~np.isnan(ds_WOD.doxy_eBoB_50_200)) & (years>1995)
# p = ax.scatter(ds_WOD.lon_eBoB[ind],ds_WOD.lat_eBoB[ind],s=sz,marker = '.',c=clrs[3],cmap=cmap,vmin=cmin,vmax=cmax,
#                        edgecolor = 'none',transform=ccrs.PlateCarree())
# land
g = add_land(ax, bounds = cbounds,countries = False, rivers = True, rcolor = 'cornflowerblue')
# g.xlocator = mticker.FixedLocator(np.arange(60,110,10))
g.xlabel_style = {'size': 5.5}
g.ylabel_style = {'size': 5.5}
g.xlocator = mticker.FixedLocator([54,66,78,90,102])
plt.title('Coastal Nitrate Observations since 1995')
# Out:
# (161,)
# Text(0.5, 1.0, 'Coastal Nitrate Observations since 1995')
