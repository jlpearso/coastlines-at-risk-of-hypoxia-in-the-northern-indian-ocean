# %%
# import packages
# %run ../global_packages.py

# get the global parameters
# %run ../global_pars.py

# import your local functions
sys.path.insert(1, '../')
from global_functions import *

# make sure the figures plot inline rather than at the end
# %matplotlib inline

import warnings
warnings.simplefilter("ignore")

# %%
figpath = '../figures/'

# %% [markdown]
# # Profiles

# %%
#WOD
ds_WOD = xr.open_dataset('../data_processing/1_WOD_Coastal/wod_coastal_processed.nc')
ds_WOD.seas_wAS
# Out:
# <xarray.DataArray 'seas_wAS' (time_wAS: 30300)>
# array([0, 0, 0, ..., 0, 0, 0])
# Coordinates:
#   * time_wAS  (time_wAS) datetime64[ns] 1958-01-16 1958-01-16 ... 2020-05-23

# %%
# DMI
ds_DMI= xr.open_dataset('../data_processing/3_DMI/dmi_processed.nc')


posIODyears = list(np.array(ds_DMI.pos_IOD_years))
sposIODyears = list(np.array(ds_DMI.spos_IOD_years))
negIODyears = list(np.array(ds_DMI.neg_IOD_years))
neuIODyears = list(np.array(ds_DMI.neu_IOD_years)) 

depth = '50_200'
Depth = '50-200'

# %%
############################################################################################################
# Western Arabian Sea
############################################################################################################
doxy = ds_WOD['doxy_wAS']
lat = ds_WOD.lat_wAS
lon = ds_WOD.lon_wAS
t = ds_WOD.time_wAS

# positive IOD years -------------------------------------------# 
posIODdata_wAS,_,_,posIODtime_wAS,posIODmon_wAS,posIODseas_wAS = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             posIODyears, region = 'wAS')
# strong positive IOD years -------------------------------------------# 
sposIODdata_wAS,_,_,sposIODtime_wAS,sposIODmon_wAS,sposIODseas_wAS = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             sposIODyears, region = 'wAS')

# negative IOD years -------------------------------------------# 
negIODdata_wAS,_,_,_,negIODmon_wAS,negIODseas_wAS = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             negIODyears, region = 'wAS')

# neutral IOD years -------------------------------------------# 
neuIODdata_wAS,_,_,_,neuIODmon_wAS,neuIODseas_wAS = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             neuIODyears, region = 'wAS')

############################################################################################################
# Eastern Arabian Sea
############################################################################################################
doxy = ds_WOD['doxy_eAS']
lat = ds_WOD.lat_eAS
lon = ds_WOD.lon_eAS
t = ds_WOD.time_eAS

# positive IOD years -------------------------------------------# 
posIODdata_eAS,_,_,_,posIODmon_eAS,posIODseas_eAS = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             posIODyears, region = 'eAS')

# strong positive IOD years -------------------------------------------# 
sposIODdata_eAS,_,_,_,sposIODmon_eAS,sposIODseas_eAS = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             sposIODyears, region = 'eAS')

# negative IOD years -------------------------------------------# 
negIODdata_eAS,_,_,_,negIODmon_eAS,negIODseas_eAS = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             negIODyears, region = 'eAS')

# neutral IOD years -------------------------------------------# 
neuIODdata_eAS,_,_,_,neuIODmon_eAS,neuIODseas_eAS = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             neuIODyears, region = 'eAS')

############################################################################################################
# Western Bay of Bengal
############################################################################################################
doxy = ds_WOD['doxy_wBoB']
lat = ds_WOD.lat_wBoB
lon = ds_WOD.lon_wBoB
t = ds_WOD.time_wBoB

# positive IOD years -------------------------------------------# 
posIODdata_wBoB,_,_,_,posIODmon_wBoB,posIODseas_wBoB = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             posIODyears, region = 'wBoB')
# strong positive IOD years -------------------------------------------# 
sposIODdata_wBoB,_,_,_,sposIODmon_wBoB,sposIODseas_wBoB = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             sposIODyears, region = 'wBoB')
# negative IOD years -------------------------------------------# 
negIODdata_wBoB,_,_,_,negIODmon_wBoB,negIODseas_wBoB = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             negIODyears, region = 'wBoB')

# neutral IOD years -------------------------------------------# 
neuIODdata_wBoB,_,_,_,neuIODmon_wBoB,neuIODseas_wBoB = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             neuIODyears, region = 'wBoB')

############################################################################################################
# Eastern Bay of Bengal
############################################################################################################
doxy = ds_WOD['doxy_eBoB']
lat = ds_WOD.lat_eBoB
lon = ds_WOD.lon_eBoB
t = ds_WOD.time_eBoB

# positive IOD years -------------------------------------------# 
posIODdata_eBoB,poslat_eBoB,poslon_eBoB,_,posIODmon_eBoB,posIODseas_eBoB = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             posIODyears, region = 'eBoB')
# strong positive IOD years -------------------------------------------# 
sposIODdata_eBoB,_,_,_,sposIODmon_eBoB,sposIODseas_eBoB = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             sposIODyears, region = 'eBoB')
# negative IOD years -------------------------------------------# 
negIODdata_eBoB,neglat_eBoB,neglon_eBoB,_,negIODmon_eBoB,negIODseas_eBoB = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             negIODyears, region = 'eBoB')

# neutral IOD years -------------------------------------------# 
neuIODdata_eBoB,neulat_eBoB,neulon_eBoB,_,neuIODmon_eBoB,neuIODseas_eBoB = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             neuIODyears, region = 'eBoB')

# %%
letters = ['a','b','c','d','e','f']
x = [1,2,3,4]

fig = plt.figure(figsize=(17.8 / 2.54, 5), dpi=400)
# ax2 = fig.add_subplot(2,1,1); ax2.yaxis.grid(color='gainsboro');ax2.set_axisbelow(True) 
# ax3 = fig.add_subplot(2,1,2); ax3.yaxis.grid(color='gainsboro');ax3.set_axisbelow(True) 

params = {'legend.fontsize': 7.5,
         'axes.labelsize': 8,
         'axes.titlesize': 8,
         'xtick.labelsize':5,
         'ytick.labelsize':5,
         'hatch.color': 'gray',
          'hatch.linewidth': 0.25,
          'axes.linewidth':0.35,
         'xtick.major.width':0.25,
         'xtick.major.size':1.5,
         'ytick.major.width':0.25,
         'ytick.major.size':1.5}

pylab.rcParams.update(params)


lw = 0.1
text_fz = 5
sq_sz = 20
lfz = 7
alpha = 0.2

cmap = plt.cm.PuOr_r
cmin = -0.15
cmax = 0.15
xlim = [0,225]
ylim = [-250,0]

regions = ['Western\nArabian Sea','Eastern\nArabian Sea','Western\nBay of Bengal','Eastern\nBay of Bengal']
labels = ['Neutral IOD Phases','Positive IOD Phases','Negative IOD Phases']
clrs = ['darkgreen','navy','darkorange']
####################################################################################################
# Plots
####################################################################################################
for ss in range(1,-1,-1):
    
    # WAS ----------------------------------------------#
    ax = fig.add_subplot(3,4,1)
    # neutral 
    seas = neuIODseas_wAS
    data = neuIODdata_wAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
        ls = ':'
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        ls = '-'
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0], ls = ls)
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[0], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    
    ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
    ax.set_xticklabels([])
    ax.set_title(regions[0])
    ax.set_ylabel('Neutral IOD Phases')

    # positive IOD
    ax = fig.add_subplot(3,4,5)
    seas = posIODseas_wAS
    data = posIODdata_wAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[1], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    
    ax.set_xticklabels([])
    ax.set_ylabel('Positive IOD Phases')
    
    # negative IOD
    ax = fig.add_subplot(3,4,9)
    seas = negIODseas_wAS
    data = negIODdata_wAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2], ls = ls)
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[2], alpha = alpha, lw = 0)

    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    
    ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
    ax.set_ylabel('Negative IOD Phases')
    
    
    # EAS ----------------------------------------------#

    # neutral 
    ax = fig.add_subplot(3,4,2)
    seas = neuIODseas_eAS
    data = neuIODdata_eAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0], ls = ls)
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[0], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.set_title(regions[0])

    # positive IOD
    ax = fig.add_subplot(3,4,6)
    seas = posIODseas_eAS
    data = posIODdata_eAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1], ls = ls)
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[1], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    
    
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    
    
    # negative IOD
    ax = fig.add_subplot(3,4,10)
    seas = negIODseas_eAS
    data = negIODdata_eAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2], ls = ls)
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[2], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    
    ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
    ax.set_yticklabels([])
    
    # WBoB ----------------------------------------------#

    # neutral 
    ax = fig.add_subplot(3,4,3)
    seas = neuIODseas_wBoB
    data = neuIODdata_wBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0], ls = ls)
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[0], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.set_title(regions[0])

    # positive IOD
    ax = fig.add_subplot(3,4,7)
    seas = posIODseas_wBoB
    data = posIODdata_wBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1], ls = ls)
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[1], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    
    # negative IOD
    ax = fig.add_subplot(3,4,11)
    seas = negIODseas_wBoB
    data = negIODdata_wBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2], ls = ls)
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[2], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    
    ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
    ax.set_yticklabels([])
    
    # EBoB ----------------------------------------------#
    
    # neutral 
    ax = fig.add_subplot(3,4,4)
    seas = neuIODseas_eBoB
    data = neuIODdata_eBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0], label = labels[0], ls = ls)
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[0], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.set_title(regions[0])

    # positive IOD
    ax = fig.add_subplot(3,4,8)
    seas = posIODseas_eBoB
    data = posIODdata_eBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1], label = labels[1], ls = ls)
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[1], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    
    # negative IOD
    ax = fig.add_subplot(3,4,12)
    seas = negIODseas_eBoB
    data = negIODdata_eBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2], label = labels[2], ls = ls)
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[2], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
    ax.set_yticklabels([])
    
    
    cnt = cnt + 4

plt.subplots_adjust(hspace = 0.07, bottom = 0.3)

# plt.savefig(figpath + 'region_iod_profiles.pdf', format='pdf', dpi = 400)

# %%
fig = plt.figure(figsize=(10,5), dpi = 400)

ax = fig.add_subplot(121)

seas = neuIODseas_eBoB
data = neuIODdata_eBoB
lat = neulat_eBoB
lon = neulon_eBoB

mean_doxy_tot = np.nanmean(np.array(ds_WOD.doxy_eBoB),0)

ind = (seas == 'JJA') | (seas  == 'SON')
doxy = data[ind]
mean_doxy = np.nanmean(doxy,0)
std_doxy = np.nanstd(doxy,0)

plt.plot(mean_doxy_tot,-1*ds_WOD.depth, color = 'k')
plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0], ls = ':')
plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                 color = clrs[0], alpha = alpha, lw = 0)

ind = (seas  == 'DJF') | (seas  == 'MAM')
doxy = data[ind]
mean_doxy = np.nanmean(doxy,0)
std_doxy = np.nanstd(doxy,0)

plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0], ls = '-')
plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                 color = clrs[0], alpha = alpha, lw = 0)
plt.ylim(ylim)
plt.xlim(xlim)

ax.set_title('Total Eastern Bay of Bengal')
ax.set_ylabel('Depth (m)')
ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')

ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)

ax = fig.add_subplot(122)

seas = neuIODseas_eBoB
data = neuIODdata_eBoB
lat = neulat_eBoB
lon = neulon_eBoB

ind = lat>15

seas = seas[ind]
data = data[ind]
lat = lat[ind]
lon = lon[ind]

ind = (seas == 'JJA') | (seas  == 'SON')
doxy = data[ind]
mean_doxy = np.nanmean(doxy,0)
std_doxy = np.nanstd(doxy,0)

plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1], ls = ':')
plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                 color = clrs[1], alpha = alpha, lw = 0)

ind = (seas  == 'DJF') | (seas  == 'MAM')
doxy = data[ind]
mean_doxy = np.nanmean(doxy,0)
std_doxy = np.nanstd(doxy,0)

plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1], ls = '-')
plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                 color = clrs[1], alpha = alpha, lw = 0)
plt.ylim(ylim)
plt.xlim(xlim)

ax = fig.add_subplot(122)

seas = neuIODseas_eBoB
data = neuIODdata_eBoB
lat = neulat_eBoB
lon = neulon_eBoB

ind = lat<15

seas = seas[ind]
data = data[ind]
lat = lat[ind]
lon = lon[ind]

ind = (seas == 'JJA') | (seas  == 'SON')
doxy = data[ind]
mean_doxy = np.nanmean(doxy,0)
std_doxy = np.nanstd(doxy,0)

plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2], ls = ':')
plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                 color = clrs[2], alpha = alpha, lw = 0)

ind = (seas  == 'DJF') | (seas  == 'MAM')
doxy = data[ind]
mean_doxy = np.nanmean(doxy,0)
std_doxy = np.nanstd(doxy,0)

plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2], ls = '-')
plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                 color = clrs[2], alpha = alpha, lw = 0)
plt.ylim(ylim)
plt.xlim(xlim)
ax.set_title('Sub-regions')
ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')

ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)


ax.scatter(np.nan,np.nan,c = clrs[0], edgecolor = 'none', label = 'All Neu. IOD Phases')
ax.scatter(np.nan,np.nan,c = clrs[1], edgecolor = 'none', label = 'Only NEBoB')
ax.scatter(np.nan,np.nan,c = clrs[2], edgecolor = 'none', label = 'Only SEBoB')
ax.plot(np.nan,np.nan,c = 'k',ls = ':', label = 'Summer/Fall')
ax.plot(np.nan,np.nan,c = 'k', label = 'Winter/Spring')
plt.legend(loc = 'lower right', handletextpad = 0.001, markerscale = 1.5)

# %%
############################################################################################################
# Western Arabian Sea
############################################################################################################
doxy = ds_WOD['temp_wAS']
lat = ds_WOD.lat_wAS
lon = ds_WOD.lon_wAS
t = ds_WOD.time_wAS

# positive IOD years -------------------------------------------# 
posIODdata_wAS,_,_,posIODtime_wAS,posIODmon_wAS,posIODseas_wAS = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             posIODyears, region = 'wAS')
# strong positive IOD years -------------------------------------------# 
sposIODdata_wAS,_,_,sposIODtime_wAS,sposIODmon_wAS,sposIODseas_wAS = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             sposIODyears, region = 'wAS')

# negative IOD years -------------------------------------------# 
negIODdata_wAS,_,_,_,negIODmon_wAS,negIODseas_wAS = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             negIODyears, region = 'wAS')

# neutral IOD years -------------------------------------------# 
neuIODdata_wAS,_,_,_,neuIODmon_wAS,neuIODseas_wAS = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             neuIODyears, region = 'wAS')

############################################################################################################
# Eastern Arabian Sea
############################################################################################################
doxy = ds_WOD['temp_eAS']
lat = ds_WOD.lat_eAS
lon = ds_WOD.lon_eAS
t = ds_WOD.time_eAS

# positive IOD years -------------------------------------------# 
posIODdata_eAS,_,_,_,posIODmon_eAS,posIODseas_eAS = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             posIODyears, region = 'eAS')

# strong positive IOD years -------------------------------------------# 
sposIODdata_eAS,_,_,_,sposIODmon_eAS,sposIODseas_eAS = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             sposIODyears, region = 'eAS')

# negative IOD years -------------------------------------------# 
negIODdata_eAS,_,_,_,negIODmon_eAS,negIODseas_eAS = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             negIODyears, region = 'eAS')

# neutral IOD years -------------------------------------------# 
neuIODdata_eAS,_,_,_,neuIODmon_eAS,neuIODseas_eAS = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             neuIODyears, region = 'eAS')

############################################################################################################
# Western Bay of Bengal
############################################################################################################
doxy = ds_WOD['temp_wBoB']
lat = ds_WOD.lat_wBoB
lon = ds_WOD.lon_wBoB
t = ds_WOD.time_wBoB

# positive IOD years -------------------------------------------# 
posIODdata_wBoB,_,_,_,posIODmon_wBoB,posIODseas_wBoB = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             posIODyears, region = 'wBoB')
# strong positive IOD years -------------------------------------------# 
sposIODdata_wBoB,_,_,_,sposIODmon_wBoB,sposIODseas_wBoB = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             sposIODyears, region = 'wBoB')
# negative IOD years -------------------------------------------# 
negIODdata_wBoB,_,_,_,negIODmon_wBoB,negIODseas_wBoB = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             negIODyears, region = 'wBoB')

# neutral IOD years -------------------------------------------# 
neuIODdata_wBoB,_,_,_,neuIODmon_wBoB,neuIODseas_wBoB = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             neuIODyears, region = 'wBoB')

############################################################################################################
# Eastern Bay of Bengal
############################################################################################################
doxy = ds_WOD['temp_eBoB']
lat = ds_WOD.lat_eBoB
lon = ds_WOD.lon_eBoB
t = ds_WOD.time_eBoB

# positive IOD years -------------------------------------------# 
posIODdata_eBoB,poslat_eBoB,poslon_eBoB,_,posIODmon_eBoB,posIODseas_eBoB = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             posIODyears, region = 'eBoB')
# strong positive IOD years -------------------------------------------# 
sposIODdata_eBoB,_,_,_,sposIODmon_eBoB,sposIODseas_eBoB = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             sposIODyears, region = 'eBoB')
# negative IOD years -------------------------------------------# 
negIODdata_eBoB,neglat_eBoB,neglon_eBoB,_,negIODmon_eBoB,negIODseas_eBoB = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             negIODyears, region = 'eBoB')

# neutral IOD years -------------------------------------------# 
neuIODdata_eBoB,neulat_eBoB,neulon_eBoB,_,neuIODmon_eBoB,neuIODseas_eBoB = IOD_year_group_WOD(doxy,
                                             lat,lon,t,
                                             IODyear_begin,IODyear_end,
                                             neuIODyears, region = 'eBoB')

# %%
letters = ['a','b','c','d','e','f']
x = [1,2,3,4]

fig = plt.figure(figsize=(17.8 / 2.54, 5), dpi=400)
# ax2 = fig.add_subplot(2,1,1); ax2.yaxis.grid(color='gainsboro');ax2.set_axisbelow(True) 
# ax3 = fig.add_subplot(2,1,2); ax3.yaxis.grid(color='gainsboro');ax3.set_axisbelow(True) 

params = {'legend.fontsize': 7.5,
         'axes.labelsize': 8,
         'axes.titlesize': 8,
         'xtick.labelsize':5,
         'ytick.labelsize':5,
         'hatch.color': 'gray',
          'hatch.linewidth': 0.25,
          'axes.linewidth':0.35,
         'xtick.major.width':0.25,
         'xtick.major.size':1.5,
         'ytick.major.width':0.25,
         'ytick.major.size':1.5}

pylab.rcParams.update(params)


lw = 0.1
text_fz = 5
sq_sz = 20
lfz = 7
alpha = 0.2

cmap = plt.cm.PuOr_r
cmin = -0.15
cmax = 0.15
xlim = [10,30]
ylim = [-250,0]

regions = ['Western\nArabian Sea','Eastern\nArabian Sea','Western\nBay of Bengal','Eastern\nBay of Bengal']
labels = ['Neutral IOD Phases','Positive IOD Phases','Negative IOD Phases']
clrs = ['darkgreen','navy','darkorange']
####################################################################################################
# Plots
####################################################################################################
for ss in range(1,-1,-1):
    
    # WAS ----------------------------------------------#
    ax = fig.add_subplot(3,4,1)
    # neutral 
    seas = neuIODseas_wAS
    data = neuIODdata_wAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
        ls = ':'
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        ls = '-'
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0], ls = ls)
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[0], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    
    ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
    ax.set_xticklabels([])
    ax.set_title(regions[0])
    ax.set_ylabel('Neutral IOD Phases')

    # positive IOD
    ax = fig.add_subplot(3,4,5)
    seas = posIODseas_wAS
    data = posIODdata_wAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[1], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    
    ax.set_xticklabels([])
    ax.set_ylabel('Positive IOD Phases')
    
    # negative IOD
    ax = fig.add_subplot(3,4,9)
    seas = negIODseas_wAS
    data = negIODdata_wAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2], ls = ls)
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[2], alpha = alpha, lw = 0)

    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    
    ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
    ax.set_ylabel('Negative IOD Phases')
    
    
    # EAS ----------------------------------------------#

    # neutral 
    ax = fig.add_subplot(3,4,2)
    seas = neuIODseas_eAS
    data = neuIODdata_eAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0], ls = ls)
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[0], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.set_title(regions[0])

    # positive IOD
    ax = fig.add_subplot(3,4,6)
    seas = posIODseas_eAS
    data = posIODdata_eAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1], ls = ls)
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[1], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    
    
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    
    
    # negative IOD
    ax = fig.add_subplot(3,4,10)
    seas = negIODseas_eAS
    data = negIODdata_eAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2], ls = ls)
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[2], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    
    ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
    ax.set_yticklabels([])
    
    # WBoB ----------------------------------------------#

    # neutral 
    ax = fig.add_subplot(3,4,3)
    seas = neuIODseas_wBoB
    data = neuIODdata_wBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0], ls = ls)
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[0], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.set_title(regions[0])

    # positive IOD
    ax = fig.add_subplot(3,4,7)
    seas = posIODseas_wBoB
    data = posIODdata_wBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1], ls = ls)
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[1], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    
    # negative IOD
    ax = fig.add_subplot(3,4,11)
    seas = negIODseas_wBoB
    data = negIODdata_wBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2], ls = ls)
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[2], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    
    ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
    ax.set_yticklabels([])
    
    # EBoB ----------------------------------------------#
    
    # neutral 
    ax = fig.add_subplot(3,4,4)
    seas = neuIODseas_eBoB
    data = neuIODdata_eBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0], label = labels[0], ls = ls)
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[0], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.set_title(regions[0])

    # positive IOD
    ax = fig.add_subplot(3,4,8)
    seas = posIODseas_eBoB
    data = posIODdata_eBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1], label = labels[1], ls = ls)
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[1], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    
    # negative IOD
    ax = fig.add_subplot(3,4,12)
    seas = negIODseas_eBoB
    data = negIODdata_eBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2], label = labels[2], ls = ls)
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[2], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
    ax.set_yticklabels([])
    
    
    cnt = cnt + 4

plt.subplots_adjust(hspace = 0.07, bottom = 0.3)

# plt.savefig(figpath + 'region_iod_profiles.pdf', format='pdf', dpi = 400)

# %%
letters = ['a','b','c','d','e','f']
x = [1,2,3,4]

fig = plt.figure(figsize=(17.8 / 2.54, 3.5), dpi=400)
# ax2 = fig.add_subplot(2,1,1); ax2.yaxis.grid(color='gainsboro');ax2.set_axisbelow(True) 
# ax3 = fig.add_subplot(2,1,2); ax3.yaxis.grid(color='gainsboro');ax3.set_axisbelow(True) 

params = {'legend.fontsize': 7.5,
         'axes.labelsize': 8,
         'axes.titlesize': 8,
         'xtick.labelsize':5,
         'ytick.labelsize':5,
         'hatch.color': 'gray',
          'hatch.linewidth': 0.25,
          'axes.linewidth':0.35,
         'xtick.major.width':0.25,
         'xtick.major.size':1.5,
         'ytick.major.width':0.25,
         'ytick.major.size':1.5}

pylab.rcParams.update(params)


lw = 0.1
text_fz = 5
sq_sz = 20
lfz = 7
alpha = 0.2

cmap = plt.cm.PuOr_r
cmin = -0.15
cmax = 0.15
xlim = [10,30]
ylim = [-250,0]

regions = ['Western\nArabian Sea','Eastern\nArabian Sea','Western\nBay of Bengal','Eastern\nBay of Bengal']
labels = ['Neutral IOD Phases','Positive IOD Phases','Negative IOD Phases']
clrs = ['darkgreen','navy','darkorange']
####################################################################################################
# Plots
####################################################################################################
cnt = 1
for ss in range(1,-1,-1):
    
    # WAS ----------------------------------------------#
    ax = fig.add_subplot(2,4,cnt)
    
    # neutral 
    seas = neuIODseas_wAS
    data = neuIODdata_wAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[0], alpha = alpha, lw = 0)

    # positive IOD
    seas = posIODseas_wAS
    data = posIODdata_wAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[1], alpha = alpha, lw = 0)
    
    # negative IOD
    seas = negIODseas_wAS
    data = negIODdata_wAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[2], alpha = alpha, lw = 0)

    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    if ss == 0:
        ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
        ax.set_ylabel('Winter/Spring')
    else:
        ax.set_xticklabels([])
        ax.set_title(regions[0])
        ax.set_ylabel('Summer/Fall')
    
    
    # EAS ----------------------------------------------#
    
    ax = fig.add_subplot(2,4,cnt+1)

    # neutral 
    seas = neuIODseas_eAS
    data = neuIODdata_eAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[0], alpha = alpha, lw = 0)

    # positive IOD
    seas = posIODseas_eAS
    data = posIODdata_eAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[1], alpha = alpha, lw = 0)
    
    # negative IOD
    seas = negIODseas_eAS
    data = negIODdata_eAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[2], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    if ss == 0:
        ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
    else:
        ax.set_xticklabels([])
        ax.set_title(regions[1])

    ax.set_yticklabels([])
    
    # WBoB ----------------------------------------------#
    
    ax = fig.add_subplot(2,4,cnt+2)

    # neutral 
    seas = neuIODseas_wBoB
    data = neuIODdata_wBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[0], alpha = alpha, lw = 0)

    # positive IOD
    seas = posIODseas_wBoB
    data = posIODdata_wBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[1], alpha = alpha, lw = 0)
    
    # negative IOD
    seas = negIODseas_wBoB
    data = negIODdata_wBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[2], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    if ss == 0:
        ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
    else:
        ax.set_xticklabels([])
        ax.set_title(regions[2])

    ax.set_yticklabels([])
    
    # EBoB ----------------------------------------------#
    
    ax = fig.add_subplot(2,4,cnt+3)

    # neutral 
    seas = neuIODseas_eBoB
    data = neuIODdata_eBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0], label = labels[0])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[0], alpha = alpha, lw = 0)

    # positive IOD
    seas = posIODseas_eBoB
    data = posIODdata_eBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1], label = labels[1])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[1], alpha = alpha, lw = 0)
    
    # negative IOD
    seas = negIODseas_eBoB
    data = negIODdata_eBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2], label = labels[2])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[2], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    if ss == 0:
        ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
    else:
        ax.set_xticklabels([])
        ax.set_title(regions[3])
        
    ax.set_yticklabels([])
    
    
    cnt = cnt + 4

plt.subplots_adjust(hspace = 0.07, bottom = 0.3)

ax.legend(loc='lower center', bbox_to_anchor=(-1.35, -.85),
          ncol=5, handlelength = 2.5)

plt.savefig(figpath + 'region_iod_profiles.pdf', format='pdf', dpi = 400)

# %%
letters = ['a','b','c','d','e','f']
x = [1,2,3,4]

fig = plt.figure(figsize=(17.8 / 2.54, 3.5), dpi=400)
# ax2 = fig.add_subplot(2,1,1); ax2.yaxis.grid(color='gainsboro');ax2.set_axisbelow(True) 
# ax3 = fig.add_subplot(2,1,2); ax3.yaxis.grid(color='gainsboro');ax3.set_axisbelow(True) 

params = {'legend.fontsize': 7.5,
         'axes.labelsize': 8,
         'axes.titlesize': 8,
         'xtick.labelsize':5,
         'ytick.labelsize':5,
         'hatch.color': 'gray',
          'hatch.linewidth': 0.25,
          'axes.linewidth':0.35,
         'xtick.major.width':0.25,
         'xtick.major.size':1.5,
         'ytick.major.width':0.25,
         'ytick.major.size':1.5}

pylab.rcParams.update(params)


lw = 0.1
text_fz = 5
sq_sz = 20
lfz = 7
alpha = 0.2

cmap = plt.cm.PuOr_r
cmin = -0.15
cmax = 0.15
xlim = [0,225]
ylim = [-250,0]

regions = ['Western\nArabian Sea','Eastern\nArabian Sea','Western\nBay of Bengal','Eastern\nBay of Bengal']
labels = ['Neutral IOD Phases','Positive IOD Phases','Negative IOD Phases']
clrs = ['darkgreen','navy','darkorange']
####################################################################################################
# Plots
####################################################################################################
cnt = 1
for ss in range(1,-1,-1):
    
    # WAS ----------------------------------------------#
    ax = fig.add_subplot(2,4,cnt)
    
    # neutral 
    seas = neuIODseas_wAS
    data = neuIODdata_wAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[0], alpha = alpha, lw = 0)

    # positive IOD
    seas = posIODseas_wAS
    data = posIODdata_wAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[1], alpha = alpha, lw = 0)
    
    # negative IOD
    seas = negIODseas_wAS
    data = negIODdata_wAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[2], alpha = alpha, lw = 0)

    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    if ss == 0:
        ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
        ax.set_ylabel('Winter/Spring')
    else:
        ax.set_xticklabels([])
        ax.set_title(regions[0])
        ax.set_ylabel('Summer/Fall')
    
    
    # EAS ----------------------------------------------#
    
    ax = fig.add_subplot(2,4,cnt+1)

    # neutral 
    seas = neuIODseas_eAS
    data = neuIODdata_eAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[0], alpha = alpha, lw = 0)

    # positive IOD
    seas = posIODseas_eAS
    data = posIODdata_eAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[1], alpha = alpha, lw = 0)
    
    # negative IOD
    seas = negIODseas_eAS
    data = negIODdata_eAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[2], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    if ss == 0:
        ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
    else:
        ax.set_xticklabels([])
        ax.set_title(regions[1])

    ax.set_yticklabels([])
    
    # WBoB ----------------------------------------------#
    
    ax = fig.add_subplot(2,4,cnt+2)

    # neutral 
    seas = neuIODseas_wBoB
    data = neuIODdata_wBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[0], alpha = alpha, lw = 0)

    # positive IOD
    seas = posIODseas_wBoB
    data = posIODdata_wBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[1], alpha = alpha, lw = 0)
    
    # negative IOD
    seas = negIODseas_wBoB
    data = negIODdata_wBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[2], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    if ss == 0:
        ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
    else:
        ax.set_xticklabels([])
        ax.set_title(regions[2])

    ax.set_yticklabels([])
    
    # EBoB ----------------------------------------------#
    
    ax = fig.add_subplot(2,4,cnt+3)

    # neutral 
    seas = neuIODseas_eBoB
    data = neuIODdata_eBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0], label = labels[0])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[0], alpha = alpha, lw = 0)

    # positive IOD
    seas = posIODseas_eBoB
    data = posIODdata_eBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1], label = labels[1])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[1], alpha = alpha, lw = 0)
    
    # negative IOD
    seas = negIODseas_eBoB
    data = negIODdata_eBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2], label = labels[2])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[2], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    if ss == 0:
        ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
    else:
        ax.set_xticklabels([])
        ax.set_title(regions[3])
        
    ax.set_yticklabels([])
    
    
    cnt = cnt + 4

plt.subplots_adjust(hspace = 0.07, bottom = 0.3)

ax.legend(loc='lower center', bbox_to_anchor=(-1.35, -.85),
          ncol=5, handlelength = 2.5)

plt.savefig(figpath + 'region_iod_profiles.pdf', format='pdf', dpi = 400)

# %%
# letters = ['a','b','c','d','e','f']
# x = [1,2,3,4]

# fig = plt.figure(figsize=(17.8 / 2.54, 3.5), dpi=400)
# # ax2 = fig.add_subplot(2,1,1); ax2.yaxis.grid(color='gainsboro');ax2.set_axisbelow(True) 
# # ax3 = fig.add_subplot(2,1,2); ax3.yaxis.grid(color='gainsboro');ax3.set_axisbelow(True) 

# params = {'legend.fontsize': 7.5,
#          'axes.labelsize': 8,
#          'axes.titlesize': 8,
#          'xtick.labelsize':5,
#          'ytick.labelsize':5,
#          'hatch.color': 'gray',
#           'hatch.linewidth': 0.25,
#           'axes.linewidth':0.35,
#          'xtick.major.width':0.25,
#          'xtick.major.size':1.5,
#          'ytick.major.width':0.25,
#          'ytick.major.size':1.5}

# pylab.rcParams.update(params)


# lw = 0.1
# text_fz = 5
# sq_sz = 20
# lfz = 7
# alpha = 0.2

# cmap = plt.cm.PuOr_r
# cmin = -0.15
# cmax = 0.15
# xlim = [-10,225]
# ylim = [-250,0]

# regions = ['Western\nArabian Sea','Eastern\nArabian Sea','Western\nBay of Bengal','Eastern\nBay of Bengal']
# labels = ['Neutral IOD Phases','Positive IOD Phases','Negative IOD Phases']
# clrs = ['darkgreen','navy','darkorange']
# ####################################################################################################
# # Plots
# ####################################################################################################
# cnt = 1
# for ss in range(1,-1,-1):
    
#     # WAS ----------------------------------------------#
#     ax = fig.add_subplot(2,4,cnt)
     
#     seas = np.array(ds_WOD.seas_wAS)
#     data = np.array(ds_WOD.doxy_wAS)
    
#     ind = seas == ss
        
#     doxy = data[ind]
#     mean_doxy = np.nanmean(doxy,0)
#     std_doxy = np.nanstd(doxy,0)
    
#     plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0])
#     plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
#                      color = clrs[0], alpha = alpha, lw = 0)

#     ax.axvspan(-10, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
#     ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
# #     ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
#     ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
#     ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
#     ax.set_ylim(ylim)
#     ax.set_xlim(xlim)
#     if ss == 0:
#         ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
#         ax.set_ylabel('Winter/Spring')
#         ax.set_xticks([0,hyp_thresh,100,150,200,250])
#         ax.set_xticklabels([0,'hyp.',100,150,200,250])
#     else:
#         ax.set_xticks([0,hyp_thresh,100,150,200,250])
#         ax.set_xticklabels([])
#         ax.set_title(regions[0])
#         ax.set_ylabel('Summer/Fall')
    
    
#     # EAS ----------------------------------------------#
    
#     ax = fig.add_subplot(2,4,cnt+1)
 
#     seas = np.array(ds_WOD.seas_eAS)
#     data = np.array(ds_WOD.doxy_eAS)
    
#     ind = seas == ss
        
#     doxy = data[ind]
#     mean_doxy = np.nanmean(doxy,0)
#     std_doxy = np.nanstd(doxy,0)
    
#     plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0])
#     plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
#                      color = clrs[0], alpha = alpha, lw = 0)

    
    
#     ax.axvspan(-10, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
#     ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
# #     ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
#     ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
#     ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
#     ax.set_ylim(ylim)
#     ax.set_xlim(xlim)
#     if ss == 0:
#         ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
#         ax.set_xticks([0,hyp_thresh,100,150,200,250])
#         ax.set_xticklabels([0,'hyp.',100,150,200,250])
#     else:
#         ax.set_xticks([0,hyp_thresh,100,150,200,250])
#         ax.set_xticklabels([])
#         ax.set_title(regions[1])

#     ax.set_yticklabels([])
    
#     # WBoB ----------------------------------------------#
    
#     ax = fig.add_subplot(2,4,cnt+2)

#     seas = np.array(ds_WOD.seas_wBoB)
#     data = np.array(ds_WOD.doxy_wBoB)
    
#     ind = seas == ss
        
#     doxy = data[ind]
#     mean_doxy = np.nanmean(doxy,0)
#     std_doxy = np.nanstd(doxy,0)
    
#     plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0])
#     plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
#                      color = clrs[0], alpha = alpha, lw = 0)

    
#     ax.axvspan(-10, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
#     ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
# #     ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
#     ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
#     ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
#     ax.set_ylim(ylim)
#     ax.set_xlim(xlim)
#     if ss == 0:
#         ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
#         ax.set_xticks([0,hyp_thresh,100,150,200,250])
#         ax.set_xticklabels([0,'hyp.',100,150,200,250])
#     else:
#         ax.set_xticks([0,hyp_thresh,100,150,200,250])
#         ax.set_xticklabels([])
#         ax.set_title(regions[2])

#     ax.set_yticklabels([])
    
#     # EBoB ----------------------------------------------#
    
#     ax = fig.add_subplot(2,4,cnt+3)

#     seas = np.array(ds_WOD.seas_eBoB)
#     data = np.array(ds_WOD.doxy_eBoB)
    
#     ind = seas == ss
        
#     doxy = data[ind]
#     mean_doxy = np.nanmean(doxy,0)
#     std_doxy = np.nanstd(doxy,0)
    
#     plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0], label = labels[0])
#     plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
#                      color = clrs[0], alpha = alpha, lw = 0)
    
#     ax.axvspan(-10, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
#     ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
# #     ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
#     ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
#     ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
#     ax.set_ylim(ylim)
#     ax.set_xlim(xlim)
#     if ss == 0:
#         ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
#         ax.set_xticks([0,hyp_thresh,100,150,200,250])
#         ax.set_xticklabels([0,'hyp',100,150,200,250])
#     else:
#         ax.set_xticks([0,hyp_thresh,100,150,200,250])
#         ax.set_xticklabels([])
#         ax.set_title(regions[3])
        
#     ax.set_yticklabels([])
    
    
#     cnt = cnt + 4

# plt.subplots_adjust(hspace = 0.07, bottom = 0.3)

# # ax.legend(loc='lower center', bbox_to_anchor=(-1.35, -.85),
# #           ncol=5, handlelength = 2.5)

# # plt.savefig(figpath + 'region_iod_profiles.pdf', format='pdf', dpi = 400)

# %%
letters = ['a','b','c','d','e','f']
x = [1,2,3,4]

fig = plt.figure(figsize=(17.8 / 2.54, 3.5), dpi=400)
# ax2 = fig.add_subplot(2,1,1); ax2.yaxis.grid(color='gainsboro');ax2.set_axisbelow(True) 
# ax3 = fig.add_subplot(2,1,2); ax3.yaxis.grid(color='gainsboro');ax3.set_axisbelow(True) 

params = {'legend.fontsize': 7.5,
         'axes.labelsize': 8,
         'axes.titlesize': 8,
         'xtick.labelsize':5,
         'ytick.labelsize':5,
         'hatch.color': 'gray',
          'hatch.linewidth': 0.25,
          'axes.linewidth':0.35,
         'xtick.major.width':0.25,
         'xtick.major.size':1.5,
         'ytick.major.width':0.25,
         'ytick.major.size':1.5}

pylab.rcParams.update(params)


lw = 0.1
text_fz = 5
sq_sz = 20
lfz = 7
alpha = 0.2

cmap = plt.cm.PuOr_r
cmin = -0.15
cmax = 0.15
xlim = [0,225]
ylim = [-250,0]

regions = ['Western\nArabian Sea','Eastern\nArabian Sea','Western\nBay of Bengal','Eastern\nBay of Bengal']
labels = ['Neutral IOD Phases','Positive IOD Phases','Negative IOD Phases']
clrs = ['darkgreen','navy','darkorange']
####################################################################################################
# Plots
####################################################################################################
cnt = 1
for ss in range(1,-1,-1):
    
    # WAS ----------------------------------------------#
    ax = fig.add_subplot(2,4,cnt)
    
    # neutral 
    seas = neuIODseas_wAS
    data = neuIODdata_wAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[0], alpha = alpha, lw = 0)

    # positive IOD
    seas = posIODseas_wAS
    data = posIODdata_wAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
#     plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1])
#     plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
#                      color = clrs[1], alpha = alpha, lw = 0)
    
    # negative IOD
    seas = negIODseas_wAS
    data = negIODdata_wAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
#     plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2])
#     plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
#                      color = clrs[2], alpha = alpha, lw = 0)

    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    if ss == 0:
        ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
        ax.set_ylabel('Winter/Spring')
    else:
        ax.set_xticklabels([])
        ax.set_title(regions[0])
        ax.set_ylabel('Summer/Fall')
    
    
    # EAS ----------------------------------------------#
    
    ax = fig.add_subplot(2,4,cnt+1)

    # neutral 
    seas = neuIODseas_eAS
    data = neuIODdata_eAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[0], alpha = alpha, lw = 0)

    # positive IOD
    seas = posIODseas_eAS
    data = posIODdata_eAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
#     plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1])
#     plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
#                      color = clrs[1], alpha = alpha, lw = 0)
    
    # negative IOD
    seas = negIODseas_eAS
    data = negIODdata_eAS
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
#     plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2])
#     plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
#                      color = clrs[2], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    if ss == 0:
        ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
    else:
        ax.set_xticklabels([])
        ax.set_title(regions[1])

    ax.set_yticklabels([])
    
    # WBoB ----------------------------------------------#
    
    ax = fig.add_subplot(2,4,cnt+2)

    # neutral 
    seas = neuIODseas_wBoB
    data = neuIODdata_wBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[0], alpha = alpha, lw = 0)

    # positive IOD
    seas = posIODseas_wBoB
    data = posIODdata_wBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
#     plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1])
#     plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
#                      color = clrs[1], alpha = alpha, lw = 0)
    
    # negative IOD
    seas = negIODseas_wBoB
    data = negIODdata_wBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
#     plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2])
#     plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
#                      color = clrs[2], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    if ss == 0:
        ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
    else:
        ax.set_xticklabels([])
        ax.set_title(regions[2])

    ax.set_yticklabels([])
    
    # EBoB ----------------------------------------------#
    
    ax = fig.add_subplot(2,4,cnt+3)

    # neutral 
    seas = neuIODseas_eBoB
    data = neuIODdata_eBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
    plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[0], label = labels[0])
    plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
                     color = clrs[0], alpha = alpha, lw = 0)

    # positive IOD
    seas = posIODseas_eBoB
    data = posIODdata_eBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
#     plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[1], label = labels[1])
#     plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
#                      color = clrs[1], alpha = alpha, lw = 0)
    
    # negative IOD
    seas = negIODseas_eBoB
    data = negIODdata_eBoB
    
    if ss == 1:
        ind = (seas == 'JJA') | (seas  == 'SON')
    else:
        ind = (seas  == 'DJF') | (seas  == 'MAM')
        
    doxy = data[ind]
    mean_doxy = np.nanmean(doxy,0)
    std_doxy = np.nanstd(doxy,0)
    
#     plt.plot(mean_doxy,-1*ds_WOD.depth, color = clrs[2], label = labels[2])
#     plt.fill_betweenx(y = -1*ds_WOD.depth, x1 = mean_doxy-std_doxy, x2 = mean_doxy+std_doxy,
#                      color = clrs[2], alpha = alpha, lw = 0)
    
    ax.axvspan(0, hyp_thresh, alpha=0.1, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -50,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axhline(y = -200,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.set_ylim(ylim)
    ax.set_xlim(xlim)
    if ss == 0:
        ax.set_xlabel('Dissovled Oxygen\n($\mu mol/kg$)')
    else:
        ax.set_xticklabels([])
        ax.set_title(regions[3])
        
    ax.set_yticklabels([])
    
    
    cnt = cnt + 4

plt.subplots_adjust(hspace = 0.07, bottom = 0.3)

# ax.legend(loc='lower center', bbox_to_anchor=(-1.35, -.85),
#           ncol=5, handlelength = 2.5)

plt.savefig(figpath + 'region_iod_profiles.pdf', format='pdf', dpi = 400)
# Out:
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:58: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:75: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:92: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:129: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:146: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:163: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:199: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:216: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:233: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:269: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:286: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:303: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:58: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:75: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:92: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:129: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:146: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:163: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:199: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:216: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:233: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:269: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:286: RuntimeWarning: Mean of empty slice
# /home/jennap/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1628: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /home/jennap/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:303: RuntimeWarning: Mean of empty slice

# %%
# Make Histograms 
# hatch_mask = min_mean > hyp_thresh
x = [1,2,3,4]

fig = plt.figure(figsize=(8.7 / 2.54, 1.5), dpi=400)

params = {'legend.fontsize': 3,
         'axes.labelsize': 3.5,
         'axes.titlesize': 5.5,
         'xtick.labelsize':3,
         'ytick.labelsize':3,
         'axes.linewidth':0.35,
         'xtick.major.width':0.25,
         'xtick.major.size':1.5,
         'ytick.major.width':0.25,
         'ytick.major.size':1.5}

pylab.rcParams.update(params)

text_fz = 4.5
sq_sz = 20
lfz = 3.75
width = 0.2
lw = 0.75

clrs = ['darkgreen','navy','darkorange','darkorchid', 'darkgreen']
labels = ['Neutral IOD Phases','Positive IOD Phases','Negative IOD Phases','Strong Positive Phases']
letters = ['a','b','c','d','e','f','g','h']


regions = ['WAS','EAS','WBoB','EBoB']

####################################################################################################

data_wAS = [neuIODdata_wAS,posIODdata_wAS,negIODdata_wAS,sposIODdata_wAS]
data_eAS = [neuIODdata_eAS,posIODdata_eAS,negIODdata_eAS,sposIODdata_eAS]
data_wBoB = [neuIODdata_wBoB,posIODdata_wBoB,negIODdata_wBoB,sposIODdata_wBoB]
data_eBoB = [neuIODdata_eBoB,posIODdata_eBoB,negIODdata_eBoB,sposIODdata_eBoB]

time_data_wAS = [neuIODmon_wAS,posIODmon_wAS,negIODmon_wAS,sposIODmon_wAS]
time_data_eAS = [neuIODmon_eAS,posIODmon_eAS,negIODmon_eAS,sposIODmon_eAS]
time_data_wBoB = [neuIODmon_wBoB,posIODmon_wBoB,negIODmon_wBoB,sposIODmon_wBoB]
time_data_eBoB = [neuIODmon_eBoB,posIODmon_eBoB,negIODmon_eBoB,sposIODmon_eBoB]


cnt = 1
for pp in range(4):

    if pp==0:
        sdata = data_wAS[0]
        pdata = data_wAS[1]
        ndata = data_wAS[2]
        spdata = data_wAS[3]
        
        stdata = time_data_wAS[0]
        ptdata = time_data_wAS[1]
        ntdata = time_data_wAS[2]
        sptdata = time_data_wAS[3]

    elif pp==1:
        sdata = data_eAS[0]
        pdata = data_eAS[1]
        ndata = data_eAS[2]
        spdata = data_eAS[3]
        
        stdata = time_data_eAS[0]
        ptdata = time_data_eAS[1]
        ntdata = time_data_eAS[2]
        sptdata = time_data_eAS[3]

    elif pp==2:
        sdata = data_wBoB[0]
        pdata = data_wBoB[1]
        ndata = data_wBoB[2]
        spdata = data_wBoB[3]
        
        stdata = time_data_wBoB[0]
        ptdata = time_data_wBoB[1]
        ntdata = time_data_wBoB[2]
        sptdata = time_data_wBoB[3]

    else:
        sdata = data_eBoB[0]
        pdata = data_eBoB[1]
        ndata = data_eBoB[2]
        spdata = data_eBoB[3]
        
        stdata = time_data_eBoB[0]
        ptdata = time_data_eBoB[1]
        ntdata = time_data_eBoB[2]
        sptdata = time_data_eBoB[3]

    # O2
    x1 = sdata[~np.isnan(sdata)]
    x2 = pdata[~np.isnan(pdata)]
    x3 = ndata[~np.isnan(ndata)]
    x4 = spdata[~np.isnan(spdata)]

    x1t = stdata[~np.isnan(sdata)]
    x2t = ptdata[~np.isnan(pdata)]
    x3t = ntdata[~np.isnan(ndata)]
    x4t = sptdata[~np.isnan(spdata)]

    # get seasonal indicies
    ind_sf = (x1t == 6) | (x1t == 7) | (x1t == 8) | (x1t == 9) | (x1t == 10) | (x1t == 11)
    ind_ws = (x1t == 12) | (x1t == 1) | (x1t == 2) | (x1t == 3) | (x1t == 4) | (x1t ==5)

    x1_sf = x1[ind_sf]
    x1_ws = x1[ind_ws]

    ind_sf = (x2t == 6) | (x2t == 7) | (x2t == 8) | (x2t == 9) | (x2t == 10) | (x2t == 11)
    ind_ws = (x2t == 12) | (x2t == 1) | (x2t == 2) | (x2t == 3) | (x2t == 4) | (x2t ==5)

    x2_sf = x2[ind_sf]
    x2_ws = x2[ind_ws]

    ind_sf = (x3t == 6) | (x3t == 7) | (x3t == 8) | (x3t == 9) | (x3t == 10) | (x3t == 11)
    ind_ws = (x3t == 12) | (x3t == 1) | (x3t == 2) | (x3t == 3) | (x3t == 4) | (x3t ==5)

    x3_sf = x3[ind_sf]
    x3_ws = x3[ind_ws]
    
    ind_sf = (x4t == 6) | (x4t == 7) | (x4t == 8) | (x4t == 9) | (x4t == 10) | (x4t == 11)
    ind_ws = (x4t == 12) | (x4t == 1) | (x4t == 2) | (x4t == 3) | (x4t == 4) | (x4t ==5)

    x4_sf = x4[ind_sf]
    x4_ws = x4[ind_ws]

    
    # sort
    x1_sf = np.sort(x1_sf)
    x2_sf = np.sort(x2_sf)
    x3_sf = np.sort(x3_sf)
    x4_sf = np.sort(x4_sf)
    
    x1_ws = np.sort(x1_ws)
    x2_ws = np.sort(x2_ws)
    x3_ws = np.sort(x3_ws)
    x4_ws = np.sort(x4_ws)
    
    # ks test
    if (len(x1_sf)>0) & (len(x2_sf)>0):
        pos_all_ks_sf = stats.ks_2samp(x1_sf,x2_sf)
    if (len(x1_sf)>0) & (len(x3_sf)>0):    
        neg_all_ks_sf = stats.ks_2samp(x1_sf,x3_sf)
    if (len(x2_sf)>0) & (len(x3_sf)>0):
        pos_neg_ks_sf = stats.ks_2samp(x2_sf,x3_sf)
    if (len(x2_sf)>0) & (len(x4_sf)>0):
        pos_spos_ks_sf = stats.ks_2samp(x2_sf,x4_sf)

    if (len(x1_ws)>0) & (len(x2_ws)>0):
        pos_all_ks_ws = stats.ks_2samp(x1_ws,x2_ws)
    if (len(x1_ws)>0) & (len(x3_ws)>0):
        neg_all_ks_ws = stats.ks_2samp(x1_ws,x3_ws)
    if (len(x2_ws)>0) & (len(x3_ws)>0):
        pos_neg_ks_ws = stats.ks_2samp(x2_ws,x3_ws)
    if (len(x2_ws)>0) & (len(x4_ws)>0):
        pos_spos_ks_ws = stats.ks_2samp(x2_ws,x4_ws)

    # summer/fall --------------------------------------------------------------- #
    ax = fig.add_subplot(2,4,cnt)
    ax.axvspan(-100, hyp_thresh, alpha=0.5, color='silver', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)
    
    # seasonal 
    tmp = np.sort(x1_sf)
    cdf = (np.arange(len(tmp))+1)/len(tmp)*100
    
    plt.plot(tmp,cdf, linewidth = lw, color = clrs[0])
    
    # positive IOD
    tmp = np.sort(x2_sf)
    cdf = (np.arange(len(tmp))+1)/len(tmp)*100
    
    plt.plot(tmp,cdf, linewidth = lw, color = clrs[1])
    
    # negative IOD
    tmp = np.sort(x3_sf)
    cdf = (np.arange(len(tmp))+1)/len(tmp)*100
    
    plt.plot(tmp,cdf, linewidth = lw, color = clrs[2])
    
    if cnt == 1:
        ax.set_ylabel('CDF \nSummer/Fall', fontsize = 4,labelpad = 1.5)
    else:
        ax.set_yticklabels([])
        
    ax.set_title(regions[pp], pad = 3)
    ax.set_xticklabels([])
        
    ax.set_xlim([0,250])
    add_letter(ax, letters[cnt-1], x = 0.01,y=0.91, fontsize = lfz)
    if (len(x1_sf)>1) & (len(x2_sf)>1):
        add_text(ax, 'K-S pos-neu: ' + str(np.round(pos_all_ks_sf[0],4)), x = 0.4,y=0.38, fontsize = 2.25)
        add_text(ax, 'p-val pos-neu: ' + str(np.round(pos_all_ks_sf[1],4)), x = 0.4,y=0.28, fontsize = 2.25)
        
    if (len(x1_sf)>1) & (len(x3_sf)>1):
        add_text(ax, 'K-S neg-neu: ' + str(np.round(neg_all_ks_sf[0],4)), x = 0.4,y=0.18, fontsize = 2.25)
        add_text(ax, 'p-val neg-neu: ' + str(np.round(neg_all_ks_sf[1],4)), x = 0.4,y=0.08, fontsize = 2.25)
        

    

    # winter/spring --------------------------------------------------------------- #
    ax = fig.add_subplot(2,4,cnt + 4)
    ax.axvspan(-100, hyp_thresh, alpha=0.5, color='silver', label = 'Hypoxia', linewidth = 0)
    ax.axvline(x = hyp_thresh,color = 'silver',linestyle = '--', linewidth = 0.35)
    ax.axvline(x = 80,color = 'silver',linestyle = '--', linewidth = 0.35)

    # seasonal 
    tmp = np.sort(x1_ws)
    cdf = (np.arange(len(tmp))+1)/len(tmp)*100
    
    ax.plot(tmp,cdf, linewidth = lw, color = clrs[0], label = labels[0])

    # positive IOD
    tmp = np.sort(x2_ws)
    cdf = (np.arange(len(tmp))+1)/len(tmp)*100
    
    ax.plot(tmp,cdf, linewidth = lw, color = clrs[1], label = labels[1])
    
    # negative IOD
    tmp = np.sort(x3_ws)
    cdf = (np.arange(len(tmp))+1)/len(tmp)*100
    
    ax.plot(tmp,cdf, linewidth = lw, color = clrs[2], label = labels[2])
    
    
    ax.set_xlim([0,250])
    if cnt == 1:
        ax.set_ylabel('CDF \nWinter/Spring', fontsize = 4,labelpad = 1.5)
    else:
        ax.set_yticklabels([])
    ax.set_xlabel(Depth + ' m [$O_2$] ($\mu mol/ kg$)', fontsize = 3)
    add_letter(ax, letters[cnt+2], x = 0.01,y=0.91, fontsize = lfz)
    if (len(x1_ws)>1) & (len(x2_ws)>1):
        add_text(ax, 'K-S pos-neu: ' + str(np.round(pos_all_ks_ws[0],4)), x = 0.4,y=0.38, fontsize = 2.25)
        add_text(ax, 'p-val pos-neu: ' + str(np.round(pos_all_ks_ws[1],4)), x = 0.4,y=0.28, fontsize = 2.25)
        
    if (len(x1_ws)>1) & (len(x3_ws)>1):
        add_text(ax, 'K-S neg-neu: ' + str(np.round(neg_all_ks_ws[0],4)), x = 0.4,y=0.18, fontsize = 2.25)
        add_text(ax, 'p-val neg-neu: ' + str(np.round(neg_all_ks_ws[1],4)), x = 0.4,y=0.08, fontsize = 2.25)
        
    cnt += 1

leg = ax.legend(loc='lower center', bbox_to_anchor=(-1.23, -.95),
          ncol=5, handlelength = 2.5)

for line in leg.get_lines():
    line.set_linewidth(1.0)

plt.subplots_adjust(wspace = 0.15, bottom = 0.3)

plt.savefig(figpath + 'Fig_S5_cdfs_' + depth + '.pdf', format='pdf', dpi = 400)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/jennap/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3325, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-d64b0d8c66a5>", line 99, in <module>
#     x1t = stdata[~np.isnan(sdata)]
# IndexError: too many indices for array
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jennap/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2039, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'IndexError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jennap/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/jennap/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "/home/jennap/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/jennap/anaconda3/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/jennap/anaconda3/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/jennap/anaconda3/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/jennap/anaconda3/lib/python3.7/inspect.py", line 742, in getmodule
#     os.path.realpath(f)] = module.__name__
# AttributeError: module has no attribute '__name__'
# ---------------------------------------------------------------------------
