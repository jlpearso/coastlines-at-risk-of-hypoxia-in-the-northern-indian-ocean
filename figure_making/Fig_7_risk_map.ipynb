# %% [markdown]
# # Setup

# %%
# import packages
# %run ../global_packages.py

# get the global parameters
# %run ../global_pars.py

# import your local functions
sys.path.insert(1, '../')
from global_functions import *

# make sure the figures plot inline rather than at the end
# %matplotlib inline

# %% [markdown]
# # Paths and Parameters

# %%
figpath = '../figures/'

# %% [markdown]
# # Get Data

# %%
ds_WOD = xr.open_dataset('../data_processing/1_WOD_Coastal/wod_coastal_processed.nc')
ds_WOD
# Out:
# <xarray.Dataset>
# Dimensions:                (depth: 97, time_eAS: 21832, time_eBoB: 20458, time_wAS: 30300, time_wBoB: 2496)
# Coordinates:
#   * time_wAS               (time_wAS) datetime64[ns] 1958-01-16 ... 2020-05-23
#   * time_eAS               (time_eAS) datetime64[ns] 1958-01-02 ... 2020-05-31
#   * time_wBoB              (time_wBoB) datetime64[ns] 1959-08-20 ... 2020-05-28
#   * time_eBoB              (time_eBoB) datetime64[ns] 1958-02-05 ... 2020-05-29
#   * depth                  (depth) int64 0 5 10 15 20 ... 4700 4800 4900 5000
# Data variables:
#     lat_wAS                (time_wAS) float32 ...
#     lon_wAS                (time_wAS) float32 ...
#     mon_wAS                (time_wAS) int64 ...
#     seas_wAS               (time_wAS) int64 ...
#     lat_eAS                (time_eAS) float32 ...
#     lon_eAS                (time_eAS) float32 ...
#     mon_eAS                (time_eAS) int64 ...
#     seas_eAS               (time_eAS) int64 ...
#     lat_wBoB               (time_wBoB) float32 ...
#     lon_wBoB               (time_wBoB) float32 ...
#     mon_wBoB               (time_wBoB) int64 ...
#     seas_wBoB              (time_wBoB) int64 ...
#     lat_eBoB               (time_eBoB) float32 ...
#     lon_eBoB               (time_eBoB) float32 ...
#     mon_eBoB               (time_eBoB) int64 ...
#     seas_eBoB              (time_eBoB) int64 ...
#     temp_wAS_50_200        (time_wAS) float64 ...
#     temp_wAS               (time_wAS, depth) float64 ...
#     sal_wAS_50_200         (time_wAS) float64 ...
#     doxy_wAS_50_200        (time_wAS) float64 ...
#     doxy_wAS               (time_wAS, depth) float64 ...
#     nitrate_wAS_50_200     (time_wAS) float64 ...
#     phosphate_wAS_50_200   (time_wAS) float64 ...
#     sol_wAS_50_200         (time_wAS) float64 ...
#     temp_eAS_50_200        (time_eAS) float64 ...
#     temp_eAS               (time_eAS, depth) float64 ...
#     sal_eAS_50_200         (time_eAS) float64 ...
#     doxy_eAS_50_200        (time_eAS) float64 ...
#     doxy_eAS               (time_eAS, depth) float64 ...
#     nitrate_eAS_50_200     (time_eAS) float64 ...
#     phosphate_eAS_50_200   (time_eAS) float64 ...
#     sol_eAS_50_200         (time_eAS) float64 ...
#     temp_wBoB_50_200       (time_wBoB) float64 ...
#     temp_wBoB              (time_wBoB, depth) float64 ...
#     sal_wBoB_50_200        (time_wBoB) float64 ...
#     doxy_wBoB_50_200       (time_wBoB) float64 ...
#     doxy_wBoB              (time_wBoB, depth) float64 ...
#     nitrate_wBoB_50_200    (time_wBoB) float64 ...
#     phosphate_wBoB_50_200  (time_wBoB) float64 ...
#     sol_wBoB_50_200        (time_wBoB) float64 ...
#     temp_eBoB_50_200       (time_eBoB) float64 ...
#     temp_eBoB              (time_eBoB, depth) float64 ...
#     sal_eBoB_50_200        (time_eBoB) float64 ...
#     doxy_eBoB_50_200       (time_eBoB) float64 ...
#     doxy_eBoB              (time_eBoB, depth) float64 ...
#     nitrate_eBoB_50_200    (time_eBoB) float64 ...
#     phosphate_eBoB_50_200  (time_eBoB) float64 ...
#     sol_eBoB_50_200        (time_eBoB) float64 ...
#     temp_wAS_40_200        (time_wAS) float64 ...
#     sal_wAS_40_200         (time_wAS) float64 ...
#     doxy_wAS_40_200        (time_wAS) float64 ...
#     nitrate_wAS_40_200     (time_wAS) float64 ...
#     phosphate_wAS_40_200   (time_wAS) float64 ...
#     temp_eAS_40_200        (time_eAS) float64 ...
#     sal_eAS_40_200         (time_eAS) float64 ...
#     doxy_eAS_40_200        (time_eAS) float64 ...
#     nitrate_eAS_40_200     (time_eAS) float64 ...
#     phosphate_eAS_40_200   (time_eAS) float64 ...
#     temp_wBoB_40_200       (time_wBoB) float64 ...
#     sal_wBoB_40_200        (time_wBoB) float64 ...
#     doxy_wBoB_40_200       (time_wBoB) float64 ...
#     nitrate_wBoB_40_200    (time_wBoB) float64 ...
#     phosphate_wBoB_40_200  (time_wBoB) float64 ...
#     temp_eBoB_40_200       (time_eBoB) float64 ...
#     sal_eBoB_40_200        (time_eBoB) float64 ...
#     doxy_eBoB_40_200       (time_eBoB) float64 ...
#     nitrate_eBoB_40_200    (time_eBoB) float64 ...
#     phosphate_eBoB_40_200  (time_eBoB) float64 ...
#     temp_wAS_50_225        (time_wAS) float64 ...
#     sal_wAS_50_225         (time_wAS) float64 ...
#     doxy_wAS_50_225        (time_wAS) float64 ...
#     nitrate_wAS_50_225     (time_wAS) float64 ...
#     phosphate_wAS_50_225   (time_wAS) float64 ...
#     temp_eAS_50_225        (time_eAS) float64 ...
#     sal_eAS_50_225         (time_eAS) float64 ...
#     doxy_eAS_50_225        (time_eAS) float64 ...
#     nitrate_eAS_50_225     (time_eAS) float64 ...
#     phosphate_eAS_50_225   (time_eAS) float64 ...
#     temp_wBoB_50_225       (time_wBoB) float64 ...
#     sal_wBoB_50_225        (time_wBoB) float64 ...
#     doxy_wBoB_50_225       (time_wBoB) float64 ...
#     nitrate_wBoB_50_225    (time_wBoB) float64 ...
#     phosphate_wBoB_50_225  (time_wBoB) float64 ...
#     temp_eBoB_50_225       (time_eBoB) float64 ...
#     sal_eBoB_50_225        (time_eBoB) float64 ...
#     doxy_eBoB_50_225       (time_eBoB) float64 ...
#     nitrate_eBoB_50_225    (time_eBoB) float64 ...
#     phosphate_eBoB_50_225  (time_eBoB) float64 ...

# %%
df = pd.read_excel('../data_processing/5_Hypoxia_Records/indian_ocean_hypoxia_records_Pearson_2021.xlsx',header = 9)
df
# Out:
#           Countries Region        Lat         Lon         Season       Year  \
# 0    Yemen and Oman    WAS  14.500000   52.000000    Summer/Fall  1960-2008
# 1    Yemen and Oman    WAS  15.500000   54.500000    Summer/Fall  1960-2008
# 2    Yemen and Oman    WAS  16.500000   56.500000    Summer/Fall  1960-2008
# 3    Yemen and Oman    WAS  18.000000   58.500000    Summer/Fall  1960-2008
# 4    Yemen and Oman    WAS  19.500000   59.500000    Summer/Fall  1960-2008
# 5    Yemen and Oman    WAS  21.500000   60.500000    Summer/Fall  1960-2008
# 6              Oman    WAS  24.000000   58.500000    Summer/Fall       1994
# 7              Oman    WAS  24.000000   58.500000  Winter/Spring       1994
# 8             India    EAS   9.978947   76.266489    Summer/Fall       2004
# 9             India    EAS  11.500000   75.200000    Summer/Fall       1958
# 10            India    EAS  10.000000   76.000000    Summer/Fall       1958
# 11            India    EAS   8.750000   76.750000    Summer/Fall       1958
# 12            India    EAS   8.000000   77.000000    Summer/Fall       1958
# 13            India    EAS  15.500000   73.700000    Summer/Fall  1997-2004
# 14            India    EAS  18.100000   73.000000    Summer/Fall       1999
# 15            India    EAS  16.250000   73.250000    Summer/Fall       1999
# 16            India    EAS  14.000000   74.000000    Summer/Fall       1999
# 17            India    EAS  13.000000   74.500000    Summer/Fall       1999
# 18            India    EAS  11.500000   74.750000    Summer/Fall       1999
# 19            India    EAS  10.000000   76.000000    Summer/Fall       1999
# 20            India    EAS   9.000000   76.500000    Summer/Fall       1999
# 21            India    EAS   8.617000   76.823000       All Year  1987-1988
# 22            India    EAS  10.394500   76.021583    Summer/Fall       2013
# 23            India    EAS  21.166667   72.758333    Summer/Fall  1983-2011
# 24            India    EAS   8.794463   78.161297       All Year       2003
# 25            India    EAS  19.150000   72.800000    Summer/Fall       2007
# 26            India    EAS  15.442295   73.794522    Summer/Fall       1980
# 27            India    EAS  22.133333   72.333330    Summer/Fall       2009
# 28           India     EAS  22.000000   69.000000    Summer/Fall       2018
# 29           India     EAS  20.000000   70.000000    Summer/Fall       2018
# ..              ...    ...        ...         ...            ...        ...
# 79            India   WBoB  13.000000   80.000000    Summer/Fall       2010
# 80            India   WBoB  13.000000   80.500000  Winter/Spring       1991
# 81            India   WBoB  13.000000   80.500000  Winter/Spring       1991
# 82            India   WBoB  20.000000   86.000000  Winter/Spring       1991
# 83            India   WBoB  20.000000   86.000000  Winter/Spring       1991
# 84            India   WBoB  17.000000   82.500000    Summer/Fall       1976
# 85            India   WBoB  19.500000   84.500000    Summer/Fall       1976
# 86            India   WBoB  12.750000   80.500000    Summer/Fall       1976
# 87            India   WBoB  15.000000   80.500000    Summer/Fall       2014
# 88            India   WBoB  12.000000   79.500000    Summer/Fall  2001-2003
# 89            India   WBoB  18.000000   86.000000       All Year  2008-2010
# 90            India   WBoB  17.250000   85.000000       All Year  2008-2010
# 91            India   WBoB  16.500000   84.000000       All Year  2008-2010
# 92            India   WBoB  15.750000   83.000000       All Year  2008-2010
# 93            India   WBoB  15.000000   82.000000       All Year  2008-2010
# 94            India   WBoB  14.250000   81.000000       All Year  2008-2010
# 95            India   WBoB  13.500000   82.000000       All Year  2008-2010
# 96            India   WBoB  12.750000   82.000000       All Year  2008-2010
# 97            India   WBoB  17.450000   83.500000  Winter/Spring       2007
# 98            India   WBoB  17.450000   83.500000  Winter/Spring       2008
# 99            India   WBoB  17.450000   83.500000  Winter/Spring       2009
# 100        Malaysia   EBoB   3.005775  101.348089    Summer/Fall  2004-2006
# 101       Indonesia   EBoB   1.383333  102.166666    Summer/Fall       2005
# 102           India   EBoB  20.500000   88.750000    Summer/Fall       1976
# 103        Malaysia   EBoB   3.000000  101.000000    Summer/Fall       2011
# 104        Malaysia   EBoB   3.000000  101.000000    Summer/Fall       2012
# 105         Myanmar   EBoB  20.000000   92.500000       All Year  2007-2009
# 106         Myanmar   EBoB  19.000000   93.000000       All Year  2007-2009
# 107         Myanmar   EBoB  17.500000   93.500000       All Year  2007-2009
# 108        Thailand   EBoB  16.000000   94.000000       All Year  2007-2009
#
#     Hypoxia Frequency                Classification  \
# 0            Seasonal                     Upwelling
# 1            Seasonal                     Upwelling
# 2            Seasonal                     Upwelling
# 3            Seasonal                     Upwelling
# 4            Seasonal                     Upwelling
# 5            Seasonal                     Upwelling
# 6             Unknown              Other or Unknown
# 7             Unknown              Other or Unknown
# 8            Seasonal  Eutrophication and Upwelling
# 9            Seasonal                     Upwelling
# 10           Seasonal                     Upwelling
# 11           Seasonal                     Upwelling
# 12           Seasonal                     Upwelling
# 13           Seasonal  Eutrophication and Upwelling
# 14           Seasonal  Eutrophication and Upwelling
# 15           Seasonal  Eutrophication and Upwelling
# 16           Seasonal  Eutrophication and Upwelling
# 17           Seasonal  Eutrophication and Upwelling
# 18           Seasonal  Eutrophication and Upwelling
# 19           Seasonal  Eutrophication and Upwelling
# 20           Seasonal  Eutrophication and Upwelling
# 21            Chronic                Eutrophication
# 22           Seasonal  Eutrophication and Upwelling
# 23           Seasonal                Eutrophication
# 24            Chronic                Eutrophication
# 25            Unknown                Eutrophication
# 26           Seasonal              Other or Unknown
# 27            Unknown                Eutrophication
# 28           Seasonal                     Upwelling
# 29           Seasonal                     Upwelling
# ..                ...                           ...
# 79           Seasonal  Eutrophication and Upwelling
# 80            Unknown              Other or Unknown
# 81            Unknown              Other or Unknown
# 82            Unknown              Other or Unknown
# 83            Unknown              Other or Unknown
# 84           Seasonal                     Upwelling
# 85           Seasonal                     Upwelling
# 86           Seasonal                     Upwelling
# 87           Episodic              Other or Unknown
# 88           Seasonal              Other or Unknown
# 89         Persistent              Other or Unknown
# 90         Persistent              Other or Unknown
# 91         Persistent              Other or Unknown
# 92         Persistent              Other or Unknown
# 93         Persistent              Other or Unknown
# 94         Persistent              Other or Unknown
# 95         Persistent              Other or Unknown
# 96         Persistent              Other or Unknown
# 97           Episodic              Other or Unknown
# 98           Episodic              Other or Unknown
# 99           Episodic              Other or Unknown
# 100          Seasonal                Eutrophication
# 101           Unknown                Eutrophication
# 102          Seasonal                     Upwelling
# 103          Seasonal              Other or Unknown
# 104          Seasonal              Other or Unknown
# 105        Persistent              Other or Unknown
# 106        Persistent              Other or Unknown
# 107        Persistent              Other or Unknown
# 108        Persistent              Other or Unknown
#
#                                                Comment  \
# 0    Defines hypoxia as <3.5ml/l in paper. Hypoxic ...
# 1    Defines hypoxia as <3.5ml/l in paper. Hypoxic ...
# 2    Defines hypoxia as <3.5ml/l in paper. Hypoxic ...
# 3    Defines hypoxia as <3.5ml/l in paper. Hypoxic ...
# 4    Defines hypoxia as <3.5ml/l in paper. Hypoxic ...
# 5    Defines hypoxia as <3.5ml/l in paper. Hypoxic ...
# 6    Hypoxia threshold not defined in paper, defaul...
# 7    Hypoxia threshold not defined in paper, defaul...
# 8    Hypoxic defined as less than 22 uM in paper.  ...
# 9    No threshold for hypoxia given in paper, using...
# 10   No threshold for hypoxia given in paper, using...
# 11   No threshold for hypoxia given in paper, using...
# 12   No threshold for hypoxia given in paper, using...
# 13   Hypoxia not defined in paper, using 62.5uM per...
# 14   Hypoxia defined as <0.5ml/l in paper. Observat...
# 15   Hypoxia defined as <0.5ml/l in paper. Observat...
# 16   Hypoxia defined as <0.5ml/l in paper. Observat...
# 17   Hypoxia defined as <0.5ml/l in paper. Observat...
# 18   Hypoxia defined as <0.5ml/l in paper. Observat...
# 19   Hypoxia defined as <0.5ml/l in paper. Observat...
# 20   Hypoxia defined as <0.5ml/l in paper. Observat...
# 21   No hypoxia threshold given in paper, using 2mg...
# 22   No hypoxia threshold given in paper, using 1.4...
# 23   Hypoxia defined as < 2mg/l in paper. From 1983...
# 24   No threshold of hypoxia given in paper, using ...
# 25   No threshold for hypoxia given in paper, using...
# 26   No hypoxia threshold given, usign 1.42ml/l per...
# 27   No hypoxia threshold given in paper, using 2mg...
# 28   Hypoxic threshold not given in paper, assuming...
# 29   Hypoxic threshold not given in paper, assuming...
# ..                                                 ...
# 79   Defines hypoxia as 0.14 < O2 < 2mg/L  and anox...
# 80   No Threshold of hypoxia given in paper. Assumi...
# 81   No Threshold of hypoxia given in paper. Assumi...
# 82   No Threshold of hypoxia given in paper. Assumi...
# 83   No Threshold of hypoxia given in paper. Assumi...
# 84   No hypoxia threshold provided in paper, using ...
# 85   No hypoxia threshold provided in paper, using ...
# 86   No hypoxia threshold provided in paper, using ...
# 87   No definition of hypoxia given in paper, using...
# 88   No hypoxia threshold provided in paper, using ...
# 89   No threshold of hypoxia given, using 61 umol/k...
# 90   No threshold of hypoxia given, using 61 umol/k...
# 91   No threshold of hypoxia given, using 61 umol/k...
# 92   No threshold of hypoxia given, using 61 umol/k...
# 93   No threshold of hypoxia given, using 61 umol/k...
# 94   No threshold of hypoxia given, using 61 umol/k...
# 95   No threshold of hypoxia given, using 61 umol/k...
# 96   No threshold of hypoxia given, using 61 umol/k...
# 97   No threshold for hypoxia given in paper, using...
# 98   No threshold for hypoxia given in paper, using...
# 99   No threshold for hypoxia given in paper, using...
# 100  Hypoxia defined as <125uM. Hypoxia noted nears...
# 101  No definition of hypoxia given in paper. Using...
# 102  No hypoxia threshold provided in paper, using ...
# 103  Hypoxia defined at 63 uM in paper. Hypoxia obs...
# 104  Hypoxia defined at 63 uM in paper. Hypoxia obs...
# 105  No threshold of hypoxia given, using 61 umol/k...
# 106  No threshold of hypoxia given, using 61 umol/k...
# 107  No threshold of hypoxia given, using 61 umol/k...
# 108  No threshold of hypoxia given, using 61 umol/k...
#
#                                              Reference
# 0    Piontkovski, S. A., & Al-Oufi, H. S. (2015). T...
# 1    Piontkovski, S. A., & Al-Oufi, H. S. (2015). T...
# 2    Piontkovski, S. A., & Al-Oufi, H. S. (2015). T...
# 3    Piontkovski, S. A., & Al-Oufi, H. S. (2015). T...
# 4    Piontkovski, S. A., & Al-Oufi, H. S. (2015). T...
# 5    Piontkovski, S. A., & Al-Oufi, H. S. (2015). T...
# 6    Piontkovski, S.A., Al-Gheilani, H.M.H., Jupp, ...
# 7    Piontkovski, S.A., Al-Gheilani, H.M.H., Jupp, ...
# 8    Martin, G.D., Muraleedharan, K.R., Vijay, J.G....
# 9    Banse, K. (1959). On upwelling and bottom-traw...
# 10   Banse, K. (1959). On upwelling and bottom-traw...
# 11   Banse, K. (1959). On upwelling and bottom-traw...
# 12   Banse, K. (1959). On upwelling and bottom-traw...
# 13   Naqvi, S.W.A., Naik, H., Pratihary, A., D'souz...
# 14   Naqvi, S.W.A., Jayakumar, D.A., Narvekar, P.V....
# 15   Naqvi, S.W.A., Jayakumar, D.A., Narvekar, P.V....
# 16   Naqvi, S.W.A., Jayakumar, D.A., Narvekar, P.V....
# 17   Naqvi, S.W.A., Jayakumar, D.A., Narvekar, P.V....
# 18   Naqvi, S.W.A., Jayakumar, D.A., Narvekar, P.V....
# 19   Naqvi, S.W.A., Jayakumar, D.A., Narvekar, P.V....
# 20   Naqvi, S.W.A., Jayakumar, D.A., Narvekar, P.V....
# 21   Nandan, S.B. and Azis, P.A. (1995). Benthic po...
# 22   Padmakumar, K. B., Thomas, L. C., Vijayan, A.,...
# 23   Ram, A., Jaiswar, J. R. M., Rokade, M. A., Bha...
# 24   Asha, P.S. and Diwakar, K. (2007). Hydrobiolog...
# 25   Vijay, R., Sardar, V.K., Dhage, S.S., Kelkar, ...
# 26   De Sousa, S.N. and Gupta, R.S. (1986). Variati...
# 27   Deshkar, S., Lakhmapurkar, J. and Gavali, D. (...
# 28   Gupta, G. V. M., Jyothibabu, R., Ramu, C. V., ...
# 29   Gupta, G. V. M., Jyothibabu, R., Ramu, C. V., ...
# ..                                                 ...
# 79   Satpathy, K.K., Panigrahi, S., Mohanty, A.K., ...
# 80   Rao, C.K., Naqvi, S.W.A., Kumar, M.D., Varapra...
# 81   Rao, C.K., Naqvi, S.W.A., Kumar, M.D., Varapra...
# 82   Rao, C.K., Naqvi, S.W.A., Kumar, M.D., Varapra...
# 83   Rao, C.K., Naqvi, S.W.A., Kumar, M.D., Varapra...
# 84   Naqvi, S.W.A., DeSousa, S.N., Fondekar, S.P. a...
# 85   Naqvi, S.W.A., DeSousa, S.N., Fondekar, S.P. a...
# 86   Naqvi, S.W.A., DeSousa, S.N., Fondekar, S.P. a...
# 87   Xu, H., Tang, D., Liu, Y. and Li, Y., 2019. Di...
# 88   Sardessai, S., Ramaiah, N., Prasanna Kumar, S....
# 89   D'Asaro, E., Altabet, M., Kumar, N.S. and Ravi...
# 90   D'Asaro, E., Altabet, M., Kumar, N.S. and Ravi...
# 91   D'Asaro, E., Altabet, M., Kumar, N.S. and Ravi...
# 92   D'Asaro, E., Altabet, M., Kumar, N.S. and Ravi...
# 93   D'Asaro, E., Altabet, M., Kumar, N.S. and Ravi...
# 94   D'Asaro, E., Altabet, M., Kumar, N.S. and Ravi...
# 95   D'Asaro, E., Altabet, M., Kumar, N.S. and Ravi...
# 96   D'Asaro, E., Altabet, M., Kumar, N.S. and Ravi...
# 97   Sarma, V.V.S.S., Sridevi, B., Maneesha, K., Sr...
# 98   Sarma, V.V.S.S., Sridevi, B., Maneesha, K., Sr...
# 99   Sarma, V.V.S.S., Sridevi, B., Maneesha, K., Sr...
# 100  Bong, C.W. and Lee, C.W., 2008. Nearshore and ...
# 101  Rixen, T., Baum, A., Pohlmann, T., Balzer, W.,...
# 102  Naqvi, S.W.A., DeSousa, S.N., Fondekar, S.P. a...
# 103  Lee, C.W., Lim, J.H., Heng, P.L., Marican, N.F...
# 104  Lee, C.W., Lim, J.H., Heng, P.L., Marican, N.F...
# 105  D'Asaro, E., Altabet, M., Kumar, N.S. and Ravi...
# 106  D'Asaro, E., Altabet, M., Kumar, N.S. and Ravi...
# 107  D'Asaro, E., Altabet, M., Kumar, N.S. and Ravi...
# 108  D'Asaro, E., Altabet, M., Kumar, N.S. and Ravi...
#
# [109 rows x 10 columns]

# %%
ds_HE = xr.Dataset.from_dataframe(df)
# add new hypoxia driver numeric colums
ds_HE.Classification[ds_HE.Classification  == 'Upwelling'] = 0
ds_HE.Classification[ds_HE.Classification  == 'Eutrophication and Upwelling'] = 0.5
ds_HE.Classification[ds_HE.Classification  == 'Eutrophication'] = 1
ds_HE.Classification[ds_HE.Classification  == 'Other or Unknown'] = 2
ds_HE
# Out:
# <xarray.Dataset>
# Dimensions:            (index: 109)
# Coordinates:
#   * index              (index) int64 0 1 2 3 4 5 6 ... 103 104 105 106 107 108
# Data variables:
#     Countries          (index) object 'Yemen and Oman' ... 'Thailand'
#     Region             (index) object 'WAS' 'WAS' 'WAS' ... 'EBoB' 'EBoB' 'EBoB'
#     Lat                (index) float64 14.5 15.5 16.5 18.0 ... 19.0 17.5 16.0
#     Lon                (index) float64 52.0 54.5 56.5 58.5 ... 93.0 93.5 94.0
#     Season             (index) object 'Summer/Fall' 'Summer/Fall' ... 'All Year'
#     Year               (index) object '1960-2008' '1960-2008' ... '2007-2009'
#     Hypoxia Frequency  (index) object 'Seasonal' 'Seasonal' ... 'Persistent'
#     Classification     (index) object 0 0 0 0 0 0 2 2 0.5 ... 1 1 0 2 2 2 2 2 2
#     Comment            (index) object 'Defines hypoxia as <3.5ml/l in paper. Hypoxic below ~25m per Fig 3, associated with upwelling during summer monsoon, and decadal shoaling of oxycline linked to warming of Arabian Sea. Note that in the average winter profile is hypoxic below 75m, coincident with the winter monsoon associated downwelling. Averages profiles over a large region in the WAS. Used a selection of points along the coast to be representative of the entire upwelling region.' ... 'No threshold of hypoxia given, using 61 umol/kg per Breitburg et al 2018. 1-3 umol/Lkgat 185 m, Float 663 per Figure 2d. Suggested riverine influx of nutrients leads to low oxygen.'
#     Reference          (index) object 'Piontkovski, S. A., & Al-Oufi, H. S. (2015). The Omani shelf hypoxia and the warming Arabian Sea. International Journal of Environmental Studies, 72(2), 256-264. https://doi.org/10.1080/00207233.2015.1012361' ... "D'Asaro, E., Altabet, M., Kumar, N.S. and Ravichandran, M., 2020. Structure of the Bay of Bengal oxygen deficient zone. Deep Sea Research Part II: Topical Studies in Oceanography, 179, p.104650. https://doi.org/10.1016/j.dsr2.2019.104650"

# %%
ds_mask = xr.open_dataset('../data_processing/1_WOD_Coastal/IO_coastal_mask.nc')
ds_mask
# Out:
# <xarray.Dataset>
# Dimensions:    (latn: 138, latw: 138, loc_wod: 316656, lonn: 216, lonw: 216)
# Coordinates:
#   * latw       (latw) float64 -1.375 -1.125 -0.875 -0.625 ... 32.38 32.62 32.88
#   * lonw       (lonw) float64 48.62 48.88 49.12 49.38 ... 101.9 102.1 102.4
#   * latn       (latn) float64 -1.5 -1.25 -1.0 -0.75 ... 32.0 32.25 32.5 32.75
#   * lonn       (lonn) float64 48.5 48.75 49.0 49.25 ... 101.5 101.8 102.0 102.2
#   * loc_wod    (loc_wod) int64 0 1 2 3 4 ... 316651 316652 316653 316654 316655
# Data variables:
#     maskw      (latw, lonw) int64 ...
#     maskn      (latn, lonn) float64 ...
#     maskw_wod  (loc_wod) bool ...
#     maskn_wod  (loc_wod) bool ...

# %% [markdown]
# # Subset for Coast

# %%
lat_slice_wAS = slice(bounds_wAS[2],bounds_wAS[3]) 
lon_slice_wAS = slice(bounds_wAS[0],bounds_wAS[1]) 

#subset gridded data
mask_wAS = ds_mask.maskn.sel(latn = lat_slice_wAS, lonn = lon_slice_wAS)
xx_wAS,yy_wAS = np.meshgrid(mask_wAS.lonn,mask_wAS.latn)
mask_wAS = mask_wAS.where(~((yy_wAS>22) & (yy_wAS<32) & (xx_wAS>45) & (xx_wAS<57.5)))
xx_wAS[np.isnan(mask_wAS)] = np.nan
yy_wAS[np.isnan(mask_wAS)] = np.nan
xx_wAS = xx_wAS.flatten()
yy_wAS = yy_wAS.flatten()

lat_slice_eAS = slice(bounds_eAS[2],bounds_eAS[3]) 
lon_slice_eAS = slice(bounds_eAS[0],bounds_eAS[1]) 
lat_slice_eAS_SL = slice(bounds_eAS_SL[2],bounds_eAS_SL[3]) 
lon_slice_eAS_SL = slice(bounds_eAS_SL[0],bounds_eAS_SL[1]) 

#subset gridded data
mask_eAS = ds_mask.maskw.sel(latw = lat_slice_eAS, lonw = lon_slice_eAS)
xx_eAS,yy_eAS = np.meshgrid(mask_eAS.lonw,mask_eAS.latw)
xx_eAS[mask_eAS == 0] = np.nan
yy_eAS[mask_eAS == 0] = np.nan
xx_eAS = xx_eAS.flatten()
yy_eAS = yy_eAS.flatten()

mask_eAS_SL = ds_mask.maskw.sel(latw = lat_slice_eAS_SL, lonw = lon_slice_eAS_SL)
xx_eAS_SL,yy_eAS_SL = np.meshgrid(mask_eAS_SL.lonw,mask_eAS_SL.latw)
xx_eAS_SL[np.array(mask_eAS_SL) == 0] = np.nan
yy_eAS_SL[np.array(mask_eAS_SL) == 0] = np.nan
xx_eAS_SL = xx_eAS_SL.flatten()
yy_eAS_SL = yy_eAS_SL.flatten()

xx_eAS = np.concatenate((xx_eAS,xx_eAS_SL),0)
yy_eAS = np.concatenate((yy_eAS,yy_eAS_SL),0)

lat_slice_wBoB = slice(bounds_wBoB[2],bounds_wBoB[3]) 
lon_slice_wBoB = slice(bounds_wBoB[0],bounds_wBoB[1]) 
lat_slice_wBoB_SL = slice(bounds_wBoB_SL[2],bounds_wBoB_SL[3])
lon_slice_wBoB_SL = slice(bounds_wBoB_SL[0],bounds_wBoB_SL[1])

#subset gridded data
mask_wBoB = ds_mask.maskn.sel(latn = lat_slice_wBoB, lonn = lon_slice_wBoB)
xx_wBoB,yy_wBoB = np.meshgrid(mask_wBoB.lonn,mask_wBoB.latn)
xx_wBoB[np.isnan(mask_wBoB)] = np.nan
yy_wBoB[np.isnan(mask_wBoB)] = np.nan
xx_wBoB = xx_wBoB.flatten()
yy_wBoB = yy_wBoB.flatten()

mask_wBoB_SL = ds_mask.maskn.sel(latn = lat_slice_wBoB_SL, lonn = lon_slice_wBoB_SL)
xx_wBoB_SL,yy_wBoB_SL = np.meshgrid(mask_wBoB_SL.lonn,mask_wBoB_SL.latn)
xx_wBoB_SL[np.isnan(np.array(mask_wBoB_SL))] = np.nan
yy_wBoB_SL[np.isnan(np.array(mask_wBoB_SL))] = np.nan
xx_wBoB_SL = xx_wBoB_SL.flatten()
yy_wBoB_SL = yy_wBoB_SL.flatten()

xx_wBoB = np.concatenate((xx_wBoB,xx_wBoB_SL),0)
yy_wBoB = np.concatenate((yy_wBoB,yy_wBoB_SL),0)

lat_slice_eBoB = slice(bounds_eBoB[2],bounds_eBoB[3]) 
lon_slice_eBoB = slice(bounds_eBoB[0],bounds_eBoB[1]) 

#subset gridded data
mask_eBoB = ds_mask.maskw.sel(latw = lat_slice_eBoB, lonw = lon_slice_eBoB)
xx_eBoB,yy_eBoB = np.meshgrid(mask_eBoB.lonw,mask_eBoB.latw)
mask_eBoB = mask_eBoB.where(~((yy_eBoB>6) & (yy_eBoB<15) & (xx_eBoB>100) & (xx_eBoB<110)),0)
mask_eBoB = mask_eBoB.where(~((yy_eBoB>8) & (yy_eBoB<15) & (xx_eBoB>99) & (xx_eBoB<110)),0)
xx_eBoB[mask_eBoB==0] = np.nan
yy_eBoB[mask_eBoB==0] = np.nan
xx_eBoB = xx_eBoB.flatten()
yy_eBoB = yy_eBoB.flatten()

# %% [markdown]
# # Plot

# %%
# # Plotting Full Indian Ocean

params = {'legend.fontsize': 8,
         'axes.labelsize': 6,
         'axes.titlesize': 9,
         'xtick.labelsize':6,
         'ytick.labelsize':6,
         'axes.linewidth':0.35}

pylab.rcParams.update(params)
cmap = cmocean.cm.thermal_r

# limits 
cbounds = [51,103,0,28.5]
cmin = 20
cmax = 160
sz = 40
# clrs = ['navy','limegreen','deeppink','purple']
clrs = ['darkorange','navy','mediumorchid','darkgreen']
hyp_clr = '#FEE12B'
sla_clr = '#FEE12B'
lfz = 6
fig = plt.figure(figsize=(17.8 / 2.54,5.5),dpi=400)

#############################################################
#----------------- Temperature ---------------------#
#############################################################
ax = fig.add_subplot(111,projection= ccrs.PlateCarree())
plt.subplots_adjust(wspace = 0.15, bottom = 0.37, top = 0.93, right = 0.98, left = 0.02)
# add_bathy(ax,cbounds)

# wAS

p = ax.scatter(xx_wAS,yy_wAS,s=sz,marker = '.',c=clrs[0],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())

# eAS

p = ax.scatter(xx_eAS,yy_eAS,s=sz,marker = '.',c=clrs[1],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())

# wBoB
p = ax.scatter(xx_wBoB,yy_wBoB,s=sz,marker = '.',c=clrs[2],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())

# eBoB
p = ax.scatter(xx_eBoB,yy_eBoB,s=sz,marker = '.',c=clrs[3],cmap=cmap,vmin=cmin,vmax=cmax,
                       edgecolor = 'none',transform=ccrs.PlateCarree())

# land
g = add_land(ax, bounds = cbounds,countries = True, rivers = True, rcolor = 'cornflowerblue',ccolor = 'k')
# g.xlocator = mticker.FixedLocator(np.arange(60,110,10))
g.ylabels_left = False
g.xlabels_bottom = False
g.xlabel_style = {'size': 6}
g.ylabel_style = {'size': 6}
g.xlocator = mticker.FixedLocator([54,78,102])


# ax.set_title('Risk of Hypoxia')

####### Hypoxia ##############################################

euclrs = ['darkmagenta','gold','limegreen','silver']
# other
ind = ds_HE.Classification == 2
ax.scatter(ds_HE.Lon[ind],ds_HE.Lat[ind],s=120,marker = '.',c=euclrs[3],lw = 0.5,
           edgecolor = 'k',transform=ccrs.PlateCarree(), zorder = 4)

# eutrophic
ind = ds_HE.Classification == 1
ax.scatter(ds_HE.Lon[ind],ds_HE.Lat[ind],s=120,marker = '.',c=euclrs[0],lw = 0.5,
           edgecolor = 'k',transform=ccrs.PlateCarree(), zorder = 4)

# upwelling
ind = ds_HE.Classification == 0
ax.scatter(ds_HE.Lon[ind],ds_HE.Lat[ind],s=120,marker = '.',c=euclrs[1],lw = 0.5,
           edgecolor = 'k',transform=ccrs.PlateCarree(), zorder = 4)

# mix 0 and 1
ind = ds_HE.Classification == 0.5
ax.scatter(ds_HE.Lon[ind],ds_HE.Lat[ind],s=120,marker = '.',c=euclrs[2],lw = 0.5,
           edgecolor = 'k',transform=ccrs.PlateCarree(), zorder = 4)

# ####### Countries ##############################################
clr = 'lightgray'
csz = 9
add_text(ax, 'India', x = 0.47,y=0.68, fontsize = csz, color = clr, weight = 'bold')
add_text(ax, 'Bangladesh', x = 0.695,y=0.82, fontsize = csz, color = clr, weight = 'bold')
add_text(ax, 'Pakistan', x = 0.245,y=0.92, fontsize = csz, color = clr, weight = 'bold')
add_text(ax, 'Iran', x = 0.14,y=0.935, fontsize = csz, color = clr, weight = 'bold')
add_text(ax, 'Oman', x = 0.08,y=0.66, fontsize = csz, color = clr, rotation = 50, weight = 'bold')
add_text(ax, 'Myanmar\n(Burma)', x = 0.82,y=0.73, fontsize = csz, color = clr, rotation = 0, weight = 'bold')
add_text(ax, 'Thailand', x = 0.9,y=0.54, fontsize = csz, color = clr, rotation = 0, weight = 'bold')
add_text(ax, 'Malaysia', x = .92,y=0.13, fontsize = csz, color = clr, rotation = -45, weight = 'bold')
add_text(ax, 'Sumatra', x = 0.87,y=0.015, fontsize = csz, color = clr, rotation = -40, weight = 'bold')
add_text(ax, 'Sri\nLanka', x = 0.56,y=0.22, fontsize = csz, color = clr, weight = 'bold')

# Seas
add_text(ax, ' Bay of \nBengal', x = 0.68,y=0.35, fontsize = 11, color = 'gray', style='italic')
add_text(ax, 'Arabian\n  Sea', x = 0.2,y=0.35, fontsize = 11, color = 'gray', style='italic')

# ####### Boxes ##############################################
tsz = 11.25
sz = 10
lw = 3
alpha = 0.15
clrs = [[255/255,140/255,0,alpha],[0,0,128/255,alpha],[186/255,85/255,211/255,alpha],[0,100/255,0,alpha]]
eclrs = ['darkorange','navy','mediumorchid','darkgreen']

y = -9.25
ax.text(57, y, " Western  \n   Arabian Sea   \n\n\n\n\n\n\n\n",
        ha="center", va="center", size=tsz,weight = 'bold',
    bbox=dict(boxstyle="square,pad=0.5", fc=clrs[0], 
              ec=eclrs[0], lw=lw))

ax.text(57, y, "\n\n\nVery high seasonal\nrisk in summer/fall\n\nWinter/spring risk\nincreased to\nmoderate during\n positive IODs\n",
        ha="center", va="center", size=sz)

ax.text(69.98, y, "   Eastern   \n    Arabian Sea    \n\n\n\n\n\n\n\n",
        ha="center", va="center", size=tsz,weight = 'bold',
    bbox=dict(boxstyle="square,pad=0.5", fc=clrs[1], 
              ec=eclrs[1], lw=lw))

ax.text(70.07, y, "\n\nHigh seasonal risk\nin summer/fall\n\nSummer/fall risk\nlowered to moderate\n in positive IODs",
        ha="center", va="center", size=sz)

ax.text(83.465, y, "   Western    \n   Bay of Bengal   \n\n\n\n\n\n\n\n",
        ha="center", va="center", size=tsz,weight = 'bold',
    bbox=dict(boxstyle="square,pad=0.5", fc=clrs[2], 
              ec=eclrs[2], lw=lw))

# ax.text(83.425, y, "\n\n\nHigh risk in\nsummer/fall\n\nWinter/Spring risk\n increased to\nmoderate during\nnegative IODs",
#         ha="center", va="center", size=sz)
 
ax.text(83.425, y, "\n\n\nHigh seasoanl risk\nin summer/fall\n\nInsufficient data\nfor IOD influence\n",
        ha="center", va="center", size=sz)

ax.text(96.8,y, "   Eastern   \n   Bay of Bengal \n\n\n\n\n\n\n\n",
        ha="center", va="center", size=tsz,weight = 'bold',
    bbox=dict(boxstyle="square,pad=0.5", fc=clrs[3], 
              ec=eclrs[3], lw=lw))

# ax.text(96.8,y, "\n\n\nModerate\n risk all year\n\nRisk increased to\n(very) high in\n(strong) positive\nIOD phases\n",
#         ha="center", va="center", size=sz)

ax.text(96.8,y, "\n\n\nModerate seasonal\nrisk all year\n\nIncreased to high all\nyear in positive IODs,\nand very high during\nstrong positive IODs\n in winter/spring",
        ha="center", va="center", size=sz-.5)

# ax.text(77.0,30, "Low Risk: < 20%       Moderate Risk: 20-40%      High Risk: 40-60%        Very High Risk: > 60%",
#         ha="center", va="center", size=9,weight = 'bold',
#        bbox=dict(boxstyle="square,pad=0.5", fc='w', 
#               ec='lightgray', lw=lw))
y = -.7
plt.annotate(' ', (55.75,y),(55.5,18),annotation_clip=False,
             arrowprops=dict(arrowstyle="-",lw=lw, color= eclrs[0]))

plt.annotate(' ', (70,y),(69.75,20),annotation_clip=False,
             arrowprops=dict(arrowstyle="-",lw=lw, color= eclrs[1]))

plt.annotate(' ', (84,y),(83.75,18),annotation_clip=False,
             arrowprops=dict(arrowstyle="-",lw=lw, color= eclrs[2]))

plt.annotate(' ', (97,y),(96.75,2),annotation_clip=False,
             arrowprops=dict(arrowstyle="-",lw=lw, color= eclrs[3]))

###### Legend #######

ax.scatter(np.nan,np.nan,s=5,marker = '.',c=euclrs[0],lw = 0.5,
                       edgecolor = 'k', label = 'Eutrophication')
ax.scatter(np.nan,np.nan,s=5,marker = '.',c=euclrs[1],lw = 0.5,
                       edgecolor = 'k', label = 'Upwelling')
ax.scatter(np.nan,np.nan,s=5,marker = '.',c=euclrs[2],lw = 0.5,
                       edgecolor = 'k', label = 'Eutroph. & Upwelling')
ax.scatter(np.nan,np.nan,s=5,marker = '.',c=euclrs[3],lw = 0.5,
                       edgecolor = 'k', label = 'Other or Unknown')
    
    
l = ax.legend(loc='lower center', bbox_to_anchor=(.795, .86),ncol = 2,
              markerscale = 6.5,facecolor = 'slategray',framealpha=1,handletextpad=0.05);
for text in l.get_texts():
    text.set_color("w")
plt.savefig(figpath + 'Fig_7_risk_map.pdf', format='pdf', dpi = 400)
